# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_raw=pd.read_csv('customer_churn_business_dataset.csv')

# %%
df_clean = df_raw.copy()

# %%
df_clean.head()
# Out:
#   customer_id  gender  age     country      city customer_segment  \
# 0  CUST_00001    Male   68  Bangladesh    London              SME
# 1  CUST_00002  Female   57      Canada    Sydney       Individual
# 2  CUST_00003    Male   24     Germany  New York              SME
# 3  CUST_00004    Male   49   Australia     Dhaka       Individual
# 4  CUST_00005    Male   65  Bangladesh     Delhi       Individual
#
#    tenure_months signup_channel contract_type  monthly_logins  ...  \
# 0             22            Web       Monthly              26  ...
# 1              9         Mobile       Monthly               7  ...
# 2             58            Web        Yearly              19  ...
# 3             19         Mobile        Yearly              34  ...
# 4             52            Web       Monthly              20  ...
#
#    avg_resolution_time  complaint_type  csat_score  escalations  \
# 0            13.354360         Service         4.0            0
# ...

# %%
df_clean.columns
# Out:
# Index(['customer_id', 'gender', 'age', 'country', 'city', 'customer_segment',
#        'tenure_months', 'signup_channel', 'contract_type', 'monthly_logins',
#        'weekly_active_days', 'avg_session_time', 'features_used',
#        'usage_growth_rate', 'last_login_days_ago', 'monthly_fee',
#        'total_revenue', 'payment_method', 'payment_failures',
#        'discount_applied', 'price_increase_last_3m', 'support_tickets',
#        'avg_resolution_time', 'complaint_type', 'csat_score', 'escalations',
#        'email_open_rate', 'marketing_click_rate', 'nps_score',
#        'survey_response', 'referral_count', 'churn'],
#       dtype='object')

# %%
df_clean.email_open_rate.value_counts()
# Out:
# email_open_rate
# 0.34    153
# 0.68    148
# 0.48    147
# 0.45    146
# 0.61    146
#        ...
# 0.43    102
# 0.51     95
# 0.38     88
# 0.10     71
# 0.90     66
# Name: count, Length: 81, dtype: int64

# %%
df_clean.payment_method.value_counts()
# Out:
# payment_method
# Card             5955
# PayPal           2557
# Bank Transfer    1488
# Name: count, dtype: int64

# %%
df_clean.complaint_type.value_counts()
# Out:
# complaint_type
# Technical    3498
# Billing      2427
# Service      2030
# Name: count, dtype: int64

# %%
df_clean.drop(columns=['customer_id'],axis=1,inplace=True)

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'country', 'city', 'customer_segment', 'tenure_months',
#        'signup_channel', 'contract_type', 'monthly_logins',
#        'weekly_active_days', 'avg_session_time', 'features_used',
#        'usage_growth_rate', 'last_login_days_ago', 'monthly_fee',
#        'total_revenue', 'payment_method', 'payment_failures',
#        'discount_applied', 'price_increase_last_3m', 'support_tickets',
#        'avg_resolution_time', 'complaint_type', 'csat_score', 'escalations',
#        'email_open_rate', 'marketing_click_rate', 'nps_score',
#        'survey_response', 'referral_count', 'churn'],
#       dtype='object')

# %%
df_clean.gender.value_counts()
# Out:
# gender
# Male      5013
# Female    4987
# Name: count, dtype: int64

# %%
df_clean.gender.value_counts()
# Out:
# gender
# Male      5013
# Female    4987
# Name: count, dtype: int64

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'country', 'city', 'customer_segment', 'tenure_months',
#        'signup_channel', 'contract_type', 'monthly_logins',
#        'weekly_active_days', 'avg_session_time', 'features_used',
#        'usage_growth_rate', 'last_login_days_ago', 'monthly_fee',
#        'total_revenue', 'payment_method', 'payment_failures',
#        'discount_applied', 'price_increase_last_3m', 'support_tickets',
#        'avg_resolution_time', 'complaint_type', 'csat_score', 'escalations',
#        'email_open_rate', 'marketing_click_rate', 'nps_score',
#        'survey_response', 'referral_count', 'churn'],
#       dtype='object')

# %%
df_clean.age.value_counts()
# Out:
# age
# 30    217
# 43    201
# 33    201
# 65    199
# 74    195
# 34    194
# 56    194
# 61    189
# 40    189
# 59    188
# 50    187
# 71    186
# 41    185
# 35    184
# 36    183
# 19    182
# 55    182
# 29    181
# 38    180
# 69    180
# 54    180
# 26    180
# 45    179
# 46    179
# 27    179
# 32    176
# 25    175
# 39    175
# 31    174
# 53    174
# 48    174
# 20    172
# 62    171
# 73    171
# 70    170
# 67    170
# 21    170
# 24    170
# 23    170
# 68    169
# 22    169
# 44    169
# 58    167
# 64    167
# 42    163
# 60    163
# 66    162
# 47    162
# 18    161
# 72    161
# 37    160
# 52    159
# 57    157
# 51    154
# 28    152
# 49    150
# 63    149
# Name: count, dtype: int64

# %%
df_clean.gender.value_counts()
# Out:
# gender
# Male      5013
# Female    4987
# Name: count, dtype: int64

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'country', 'city', 'customer_segment', 'tenure_months',
#        'signup_channel', 'contract_type', 'monthly_logins',
#        'weekly_active_days', 'avg_session_time', 'features_used',
#        'usage_growth_rate', 'last_login_days_ago', 'monthly_fee',
#        'total_revenue', 'payment_method', 'payment_failures',
#        'discount_applied', 'price_increase_last_3m', 'support_tickets',
#        'avg_resolution_time', 'complaint_type', 'csat_score', 'escalations',
#        'email_open_rate', 'marketing_click_rate', 'nps_score',
#        'survey_response', 'referral_count', 'churn'],
#       dtype='object')

# %%
df_clean.country.value_counts()
# Out:
# country
# Bangladesh    1494
# Canada        1488
# USA           1442
# India         1427
# Australia     1400
# UK            1382
# Germany       1367
# Name: count, dtype: int64

# %%
df_clean.city.value_counts()
# Out:
# city
# London      1518
# Sydney      1471
# Dhaka       1459
# Delhi       1402
# Berlin      1386
# New York    1385
# Toronto     1379
# Name: count, dtype: int64

# %%
df_clean.isnull().sum()
# Out:
# gender                       0
# age                          0
# country                      0
# city                         0
# customer_segment             0
# tenure_months                0
# signup_channel               0
# contract_type                0
# monthly_logins               0
# weekly_active_days           0
# avg_session_time             0
# features_used                0
# usage_growth_rate            0
# last_login_days_ago          0
# monthly_fee                  0
# total_revenue                0
# payment_method               0
# payment_failures             0
# discount_applied             0
# price_increase_last_3m       0
# support_tickets              0
# avg_resolution_time          0
# complaint_type            2045
# csat_score                   0
# escalations                  0
# email_open_rate              0
# marketing_click_rate         0
# nps_score                    0
# survey_response              0
# referral_count               0
# ...

# %%
df_clean.complaint_type.value_counts()
# Out:
# complaint_type
# Technical    3498
# Billing      2427
# Service      2030
# Name: count, dtype: int64

# %%
df_clean['complaint_type']=df_clean['complaint_type'].fillna('No complaint')

# %%
df_clean.complaint_type.value_counts()
# Out:
# complaint_type
# Technical       3498
# Billing         2427
# No complaint    2045
# Service         2030
# Name: count, dtype: int64

# %%
df_clean.isnull().sum()
# Out:
# gender                    0
# age                       0
# country                   0
# city                      0
# customer_segment          0
# tenure_months             0
# signup_channel            0
# contract_type             0
# monthly_logins            0
# weekly_active_days        0
# avg_session_time          0
# features_used             0
# usage_growth_rate         0
# last_login_days_ago       0
# monthly_fee               0
# total_revenue             0
# payment_method            0
# payment_failures          0
# discount_applied          0
# price_increase_last_3m    0
# support_tickets           0
# avg_resolution_time       0
# complaint_type            0
# csat_score                0
# escalations               0
# email_open_rate           0
# marketing_click_rate      0
# nps_score                 0
# survey_response           0
# referral_count            0
# churn                     0
# dtype: int64

# %%
audit_matrix = pd.crosstab(df_clean['city'], df_clean['country'])
print(audit_matrix)
# Out:
# country   Australia  Bangladesh  Canada  Germany  India   UK  USA
# city
# Berlin          200         220     190      182    206  187  201
# Delhi           185         212     228      189    185  184  219
# Dhaka           200         204     236      196    208  202  213
# London          235         224     219      203    220  202  215
# New York        198         212     217      187    195  180  196
# Sydney          189         195     212      223    208  231  213
# Toronto         193         227     186      187    205  196  185

# %%
correct_geo = {
    'London': 'UK',
    'Sydney': 'Australia',
    'Dhaka': 'Bangladesh',
    'Delhi': 'India',
    'Berlin': 'Germany',
    'New York': 'USA',
    'Toronto': 'Canada'
}

# %%
df_clean['country'] = df_clean['city'].map(correct_geo)

# %%
print(df_clean[['city', 'country']].value_counts())
# Out:
# city      country
# London    UK            1518
# Sydney    Australia     1471
# Dhaka     Bangladesh    1459
# Delhi     India         1402
# Berlin    Germany       1386
# New York  USA           1385
# Toronto   Canada        1379
# Name: count, dtype: int64

# %%
audit_matrix = pd.crosstab(df_clean['city'], df_clean['country'])
print(audit_matrix)
# Out:
# country   Australia  Bangladesh  Canada  Germany  India    UK   USA
# city
# Berlin            0           0       0     1386      0     0     0
# Delhi             0           0       0        0   1402     0     0
# Dhaka             0        1459       0        0      0     0     0
# London            0           0       0        0      0  1518     0
# New York          0           0       0        0      0     0  1385
# Sydney         1471           0       0        0      0     0     0
# Toronto           0           0    1379        0      0     0     0

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'country', 'city', 'customer_segment', 'tenure_months',
#        'signup_channel', 'contract_type', 'monthly_logins',
#        'weekly_active_days', 'avg_session_time', 'features_used',
#        'usage_growth_rate', 'last_login_days_ago', 'monthly_fee',
#        'total_revenue', 'payment_method', 'payment_failures',
#        'discount_applied', 'price_increase_last_3m', 'support_tickets',
#        'avg_resolution_time', 'complaint_type', 'csat_score', 'escalations',
#        'email_open_rate', 'marketing_click_rate', 'nps_score',
#        'survey_response', 'referral_count', 'churn'],
#       dtype='object')

# %%
df_clean.drop(columns=['country'],inplace=True,errors='ignore')

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'tenure_months',
#        'signup_channel', 'contract_type', 'monthly_logins',
#        'weekly_active_days', 'avg_session_time', 'features_used',
#        'usage_growth_rate', 'last_login_days_ago', 'monthly_fee',
#        'total_revenue', 'payment_method', 'payment_failures',
#        'discount_applied', 'price_increase_last_3m', 'support_tickets',
#        'avg_resolution_time', 'complaint_type', 'csat_score', 'escalations',
#        'email_open_rate', 'marketing_click_rate', 'nps_score',
#        'survey_response', 'referral_count', 'churn'],
#       dtype='object')

# %%
df_clean.customer_segment.value_counts()
# Out:
# customer_segment
# Individual    5984
# SME           3029
# Enterprise     987
# Name: count, dtype: int64

# %%
df_clean.tenure_months.value_counts()
# Out:
# tenure_months
# 58    208
# 36    204
# 22    189
# 42    187
# 30    186
# 51    184
# 29    184
# 34    182
# 21    181
# 28    180
# 39    179
# 45    179
# 23    178
# 24    178
# 8     177
# 41    176
# 53    176
# 7     176
# 1     175
# 44    175
# 10    174
# 4     174
# 16    174
# 55    173
# 6     173
# 56    173
# 3     173
# 50    172
# 2     172
# 47    171
# 17    170
# 20    170
# 57    170
# 26    170
# 54    167
# 11    167
# 59    166
# 27    166
# 12    166
# 52    165
# 5     165
# 31    165
# 40    164
# 43    163
# 35    162
# 38    161
# 9     158
# 18    157
# 32    155
# 46    153
# 13    152
# 37    151
# 33    151
# 48    151
# 15    151
# 49    150
# 14    146
# 25    144
# 19    141
# Name: count, dtype: int64

# %%
sns.histplot(df_clean['tenure_months'], kde=True)
plt.title("Tenure Distribution Audit")
plt.show()

# %%
# Binning the 'tenure_months' columns

# %%
bins = [0, 12, 36, 60]
labels = ['New', 'Established', 'Loyal']

# %%
df_clean['tenure_group'] = pd.cut(df_clean['tenure_months'], bins=bins, labels=labels)

# %%
print(df_clean[['tenure_months', 'tenure_group']].head())
# Out:
#    tenure_months tenure_group
# 0             22  Established
# 1              9          New
# 2             58        Loyal
# 3             19  Established
# 4             52        Loyal

# %%
df_clean.tenure_months.value_counts()
# Out:
# tenure_months
# 58    208
# 36    204
# 22    189
# 42    187
# 30    186
# 51    184
# 29    184
# 34    182
# 21    181
# 28    180
# 39    179
# 45    179
# 23    178
# 24    178
# 8     177
# 41    176
# 53    176
# 7     176
# 1     175
# 44    175
# 10    174
# 4     174
# 16    174
# 55    173
# 6     173
# 56    173
# 3     173
# 50    172
# 2     172
# 47    171
# 17    170
# 20    170
# 57    170
# 26    170
# 54    167
# 11    167
# 59    166
# 27    166
# 12    166
# 52    165
# 5     165
# 31    165
# 40    164
# 43    163
# 35    162
# 38    161
# 9     158
# 18    157
# 32    155
# 46    153
# 13    152
# 37    151
# 33    151
# 48    151
# 15    151
# 49    150
# 14    146
# 25    144
# 19    141
# Name: count, dtype: int64

# %%
df_clean.head()
# Out:
#    gender  age      city customer_segment  tenure_months signup_channel  \
# 0    Male   68    London              SME             22            Web
# 1  Female   57    Sydney       Individual              9         Mobile
# 2    Male   24  New York              SME             58            Web
# 3    Male   49     Dhaka       Individual             19         Mobile
# 4    Male   65     Delhi       Individual             52            Web
#
#   contract_type  monthly_logins  weekly_active_days  avg_session_time  ...  \
# 0       Monthly              26                   7         11.762372  ...
# 1       Monthly               7                   5         26.846390  ...
# 2        Yearly              19                   5         23.380065  ...
# 3        Yearly              34                   7         24.243136  ...
# 4       Monthly              20                   6         18.872323  ...
#
#    complaint_type  csat_score  escalations  email_open_rate  \
# ...

# %%
df_clean.drop(columns=['tenure_months'],inplace=True,errors='ignore')

# %%
df_clean.head()
# Out:
#    gender  age      city customer_segment signup_channel contract_type  \
# 0    Male   68    London              SME            Web       Monthly
# 1  Female   57    Sydney       Individual         Mobile       Monthly
# 2    Male   24  New York              SME            Web        Yearly
# 3    Male   49     Dhaka       Individual         Mobile        Yearly
# 4    Male   65     Delhi       Individual            Web       Monthly
#
#    monthly_logins  weekly_active_days  avg_session_time  features_used  ...  \
# 0              26                   7         11.762372              5  ...
# 1               7                   5         26.846390              1  ...
# 2              19                   5         23.380065              6  ...
# 3              34                   7         24.243136              2  ...
# 4              20                   6         18.872323              2  ...
#
#    complaint_type  csat_score  escalations  email_open_rate  \
# ...

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'avg_session_time', 'features_used', 'usage_growth_rate',
#        'last_login_days_ago', 'monthly_fee', 'total_revenue', 'payment_method',
#        'payment_failures', 'discount_applied', 'price_increase_last_3m',
#        'support_tickets', 'avg_resolution_time', 'complaint_type',
#        'csat_score', 'escalations', 'email_open_rate', 'marketing_click_rate',
#        'nps_score', 'survey_response', 'referral_count', 'churn',
#        'tenure_group'],
#       dtype='object')

# %%
df_clean.city.value_counts()
# Out:
# city
# London      1518
# Sydney      1471
# Dhaka       1459
# Delhi       1402
# Berlin      1386
# New York    1385
# Toronto     1379
# Name: count, dtype: int64

# %%
print(df_clean.city.isnull().sum())
# Out:
# 0

# %%
df_clean.isnull().sum()
# Out:
# gender                    0
# age                       0
# city                      0
# customer_segment          0
# signup_channel            0
# contract_type             0
# monthly_logins            0
# weekly_active_days        0
# avg_session_time          0
# features_used             0
# usage_growth_rate         0
# last_login_days_ago       0
# monthly_fee               0
# total_revenue             0
# payment_method            0
# payment_failures          0
# discount_applied          0
# price_increase_last_3m    0
# support_tickets           0
# avg_resolution_time       0
# complaint_type            0
# csat_score                0
# escalations               0
# email_open_rate           0
# marketing_click_rate      0
# nps_score                 0
# survey_response           0
# referral_count            0
# churn                     0
# tenure_group              0
# dtype: int64

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   gender                  10000 non-null  object
#  1   age                     10000 non-null  int64
#  2   city                    10000 non-null  object
#  3   customer_segment        10000 non-null  object
#  4   signup_channel          10000 non-null  object
#  5   contract_type           10000 non-null  object
#  6   monthly_logins          10000 non-null  int64
#  7   weekly_active_days      10000 non-null  int64
#  8   avg_session_time        10000 non-null  float64
#  9   features_used           10000 non-null  int64
#  10  usage_growth_rate       10000 non-null  float64
#  11  last_login_days_ago     10000 non-null  int64
#  12  monthly_fee             10000 non-null  int64
#  13  total_revenue           10000 non-null  int64
# ...

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'avg_session_time', 'features_used', 'usage_growth_rate',
#        'last_login_days_ago', 'monthly_fee', 'total_revenue', 'payment_method',
#        'payment_failures', 'discount_applied', 'price_increase_last_3m',
#        'support_tickets', 'avg_resolution_time', 'complaint_type',
#        'csat_score', 'escalations', 'email_open_rate', 'marketing_click_rate',
#        'nps_score', 'survey_response', 'referral_count', 'churn',
#        'tenure_group'],
#       dtype='object')

# %%
df_clean.signup_channel.value_counts()
# Out:
# signup_channel
# Web         5036
# Mobile      2960
# Referral    2004
# Name: count, dtype: int64

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'avg_session_time', 'features_used', 'usage_growth_rate',
#        'last_login_days_ago', 'monthly_fee', 'total_revenue', 'payment_method',
#        'payment_failures', 'discount_applied', 'price_increase_last_3m',
#        'support_tickets', 'avg_resolution_time', 'complaint_type',
#        'csat_score', 'escalations', 'email_open_rate', 'marketing_click_rate',
#        'nps_score', 'survey_response', 'referral_count', 'churn',
#        'tenure_group'],
#       dtype='object')

# %%
df_clean.signup_channel.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: signup_channel, Length: 10000, dtype: bool

# %%
df_clean.signup_channel.unique()
# Out:
# array(['Web', 'Mobile', 'Referral'], dtype=object)

# %%
cat_features = ['city', 'customer_segment', 'signup_channel', 'tenure_group']

# %%
cat_features.append(df_clean['avg_resolution_time'])

# %%
cat_features
# Out:
# ['city',
#  'customer_segment',
#  'signup_channel',
#  'tenure_group',
#  0       13.354360
#  1       25.140088
#  2       27.572928
#  3       26.420822
#  4       26.674579
#            ...
#  9995    34.240174
#  9996    40.092087
#  9997    25.215810
#  9998    20.544921
#  9999    23.536914
#  Name: avg_resolution_time, Length: 10000, dtype: float64]

# %%
#cat_features.remove(df_clean['avg_resolution_time'])

# %%
cat_features = ['city', 'customer_segment', 'signup_channel', 'tenure_group']

# %%
print([type(f) for f in cat_features])
# Out:
# [<class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>]

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'avg_session_time', 'features_used', 'usage_growth_rate',
#        'last_login_days_ago', 'monthly_fee', 'total_revenue', 'payment_method',
#        'payment_failures', 'discount_applied', 'price_increase_last_3m',
#        'support_tickets', 'avg_resolution_time', 'complaint_type',
#        'csat_score', 'escalations', 'email_open_rate', 'marketing_click_rate',
#        'nps_score', 'survey_response', 'referral_count', 'churn',
#        'tenure_group'],
#       dtype='object')

# %%
df_clean.contract_type.unique()
# Out:
# array(['Monthly', 'Yearly', 'Quarterly'], dtype=object)

# %%
df_clean.contract_type.value_counts()
# Out:
# contract_type
# Monthly      4967
# Quarterly    3050
# Yearly       1983
# Name: count, dtype: int64

# %%
df_clean.isnull().sum()
# Out:
# gender                    0
# age                       0
# city                      0
# customer_segment          0
# signup_channel            0
# contract_type             0
# monthly_logins            0
# weekly_active_days        0
# avg_session_time          0
# features_used             0
# usage_growth_rate         0
# last_login_days_ago       0
# monthly_fee               0
# total_revenue             0
# payment_method            0
# payment_failures          0
# discount_applied          0
# price_increase_last_3m    0
# support_tickets           0
# avg_resolution_time       0
# complaint_type            0
# csat_score                0
# escalations               0
# email_open_rate           0
# marketing_click_rate      0
# nps_score                 0
# survey_response           0
# referral_count            0
# churn                     0
# tenure_group              0
# dtype: int64

# %%
cat_features
# Out:
# ['city', 'customer_segment', 'signup_channel', 'tenure_group']

# %%
df_clean.complaint_type.value_counts()
# Out:
# complaint_type
# Technical       3498
# Billing         2427
# No complaint    2045
# Service         2030
# Name: count, dtype: int64

# %%
contract_map = {'Monthly': 1, 'Quarterly': 2, 'Yearly': 3}

# %%
df_clean['contract_type'] = df_clean['contract_type'].map(contract_map)

# %%
df_clean.contract_type.value_counts()
# Out:
# contract_type
# 1    4967
# 2    3050
# 3    1983
# Name: count, dtype: int64

# %%
num_features = ['contract_type']

# %%
cat_features
# Out:
# ['city', 'customer_segment', 'signup_channel', 'tenure_group']

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'avg_session_time', 'features_used', 'usage_growth_rate',
#        'last_login_days_ago', 'monthly_fee', 'total_revenue', 'payment_method',
#        'payment_failures', 'discount_applied', 'price_increase_last_3m',
#        'support_tickets', 'avg_resolution_time', 'complaint_type',
#        'csat_score', 'escalations', 'email_open_rate', 'marketing_click_rate',
#        'nps_score', 'survey_response', 'referral_count', 'churn',
#        'tenure_group'],
#       dtype='object')

# %%
df_clean.monthly_logins.value_counts()
# Out:
# monthly_logins
# 17    411
# 21    401
# 23    397
# 22    397
# 19    386
# 18    385
# 20    375
# 16    373
# 25    373
# 24    364
# 15    347
# 14    336
# 13    332
# 12    326
# 0     299
# 27    290
# 28    288
# 29    274
# 10    261
# 26    257
# 11    252
# 30    226
# 9     221
# 8     215
# 31    194
# 32    191
# 6     176
# 7     163
# 33    162
# 35    128
# 5     125
# 34    122
# 4     111
# 36    106
# 3      99
# 37     87
# 2      81
# 38     79
# 1      78
# 39     66
# 40     55
# 41     36
# 42     35
# 44     28
# 43     27
# 45     16
# 46     14
# 47     12
# 49      7
# 51      6
# 48      5
# 50      4
# 54      1
# Name: count, dtype: int64

# %%
df_clean.weekly_active_days.value_counts()
# Out:
# weekly_active_days
# 0    1322
# 5    1266
# 2    1255
# 6    1254
# 4    1247
# 7    1229
# 1    1221
# 3    1206
# Name: count, dtype: int64

# %%
df_clean.avg_session_time.value_counts()
# Out:
# avg_session_time
# 1.000000     224
# 11.762372      1
# 16.233166      1
# 15.796123      1
# 18.153751      1
#             ...
# 20.858267      1
# 9.890215       1
# 19.716282      1
# 18.606614      1
# 14.793549      1
# Name: count, Length: 9777, dtype: int64

# %%
df_clean.features_used.value_counts()
# Out:
# features_used
# 4     1767
# 5     1746
# 6     1501
# 3     1394
# 7     1013
# 2      834
# 8      656
# 1      424
# 9      359
# 10     185
# 11      69
# 12      30
# 13      18
# 14       3
# 15       1
# Name: count, dtype: int64

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'avg_session_time', 'features_used', 'usage_growth_rate',
#        'last_login_days_ago', 'monthly_fee', 'total_revenue', 'payment_method',
#        'payment_failures', 'discount_applied', 'price_increase_last_3m',
#        'support_tickets', 'avg_resolution_time', 'complaint_type',
#        'csat_score', 'escalations', 'email_open_rate', 'marketing_click_rate',
#        'nps_score', 'survey_response', 'referral_count', 'churn',
#        'tenure_group'],
#       dtype='object')

# %%
df_clean.contract_type.value_counts()
# Out:
# contract_type
# 1    4967
# 2    3050
# 3    1983
# Name: count, dtype: int64

# %%
num_features
# Out:
# ['contract_type']

# %%
df_clean.monthly_logins.value_counts()
# Out:
# monthly_logins
# 17    411
# 21    401
# 23    397
# 22    397
# 19    386
# 18    385
# 20    375
# 16    373
# 25    373
# 24    364
# 15    347
# 14    336
# 13    332
# 12    326
# 0     299
# 27    290
# 28    288
# 29    274
# 10    261
# 26    257
# 11    252
# 30    226
# 9     221
# 8     215
# 31    194
# 32    191
# 6     176
# 7     163
# 33    162
# 35    128
# 5     125
# 34    122
# 4     111
# 36    106
# 3      99
# 37     87
# 2      81
# 38     79
# 1      78
# 39     66
# 40     55
# 41     36
# 42     35
# 44     28
# 43     27
# 45     16
# 46     14
# 47     12
# 49      7
# 51      6
# 48      5
# 50      4
# 54      1
# Name: count, dtype: int64

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   gender                  10000 non-null  object
#  1   age                     10000 non-null  int64
#  2   city                    10000 non-null  object
#  3   customer_segment        10000 non-null  object
#  4   signup_channel          10000 non-null  object
#  5   contract_type           10000 non-null  int64
#  6   monthly_logins          10000 non-null  int64
#  7   weekly_active_days      10000 non-null  int64
#  8   avg_session_time        10000 non-null  float64
#  9   features_used           10000 non-null  int64
#  10  usage_growth_rate       10000 non-null  float64
#  11  last_login_days_ago     10000 non-null  int64
#  12  monthly_fee             10000 non-null  int64
#  13  total_revenue           10000 non-null  int64
# ...

# %%
df_clean['is_zombie_user'] = (df_clean['monthly_logins'] == 0).astype(int)

# %%
df_clean.is_zombie_user.value_counts()
# Out:
# is_zombie_user
# 0    9701
# 1     299
# Name: count, dtype: int64

# %%
num_features.append(df_clean['monthly_logins'])

# %%
num_features
# Out:
# ['contract_type',
#  0       26
#  1        7
#  2       19
#  3       34
#  4       20
#          ..
#  9995    15
#  9996    13
#  9997    15
#  9998    14
#  9999    15
#  Name: monthly_logins, Length: 10000, dtype: int64]

# %%
num_features.pop()
# Out:
# 0       26
# 1        7
# 2       19
# 3       34
# 4       20
#         ..
# 9995    15
# 9996    13
# 9997    15
# 9998    14
# 9999    15
# Name: monthly_logins, Length: 10000, dtype: int64

# %%
num_features.pop()
# Out:
# 'contract_type'

# %%
num_features.append('monthly_logins')

# %%
num_features
# Out:
# ['monthly_logins']

# %%
num_features.append('contract_type')

# %%
num_features
# Out:
# ['monthly_logins', 'contract_type']

# %%
df_clean.contract_type.value_counts()
# Out:
# contract_type
# 1    4967
# 2    3050
# 3    1983
# Name: count, dtype: int64

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'avg_session_time', 'features_used', 'usage_growth_rate',
#        'last_login_days_ago', 'monthly_fee', 'total_revenue', 'payment_method',
#        'payment_failures', 'discount_applied', 'price_increase_last_3m',
#        'support_tickets', 'avg_resolution_time', 'complaint_type',
#        'csat_score', 'escalations', 'email_open_rate', 'marketing_click_rate',
#        'nps_score', 'survey_response', 'referral_count', 'churn',
#        'tenure_group', 'is_zombie_user'],
#       dtype='object')

# %%
cat_features
# Out:
# ['city', 'customer_segment', 'signup_channel', 'tenure_group']

# %%
num_features.append('is_zombie_user')

# %%
df_clean.signup_channel.value_counts()
# Out:
# signup_channel
# Web         5036
# Mobile      2960
# Referral    2004
# Name: count, dtype: int64

# %%
df_clean.tenure_group.value_counts()
# Out:
# tenure_group
# Established    4036
# Loyal          3914
# New            2050
# Name: count, dtype: int64

# %%
num_features
# Out:
# ['monthly_logins', 'contract_type', 'is_zombie_user']

# %%
df_clean.contract_type.value_counts()
# Out:
# contract_type
# 1    4967
# 2    3050
# 3    1983
# Name: count, dtype: int64

# %%
cat_features
# Out:
# ['city', 'customer_segment', 'signup_channel', 'tenure_group']

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'avg_session_time', 'features_used', 'usage_growth_rate',
#        'last_login_days_ago', 'monthly_fee', 'total_revenue', 'payment_method',
#        'payment_failures', 'discount_applied', 'price_increase_last_3m',
#        'support_tickets', 'avg_resolution_time', 'complaint_type',
#        'csat_score', 'escalations', 'email_open_rate', 'marketing_click_rate',
#        'nps_score', 'survey_response', 'referral_count', 'churn',
#        'tenure_group', 'is_zombie_user'],
#       dtype='object')

# %%
df_clean.monthly_logins.value_counts()
# Out:
# monthly_logins
# 17    411
# 21    401
# 23    397
# 22    397
# 19    386
# 18    385
# 20    375
# 16    373
# 25    373
# 24    364
# 15    347
# 14    336
# 13    332
# 12    326
# 0     299
# 27    290
# 28    288
# 29    274
# 10    261
# 26    257
# 11    252
# 30    226
# 9     221
# 8     215
# 31    194
# 32    191
# 6     176
# 7     163
# 33    162
# 35    128
# 5     125
# 34    122
# 4     111
# 36    106
# 3      99
# 37     87
# 2      81
# 38     79
# 1      78
# 39     66
# 40     55
# 41     36
# 42     35
# 44     28
# 43     27
# 45     16
# 46     14
# 47     12
# 49      7
# 51      6
# 48      5
# 50      4
# 54      1
# Name: count, dtype: int64

# %%
sns.histplot(df_clean['monthly_logins'],bins=30,kde=True,color='green')
# Out:
# <Axes: xlabel='monthly_logins', ylabel='Count'>

# %%
upper_limit = df_clean['monthly_logins'].quantile(0.99)
df_clean['monthly_logins'] = df_clean['monthly_logins'].clip(upper=upper_limit)

# %%
df_clean.monthly_logins.value_counts()
# Out:
# monthly_logins
# 17    411
# 21    401
# 23    397
# 22    397
# 19    386
# 18    385
# 20    375
# 16    373
# 25    373
# 24    364
# 15    347
# 14    336
# 13    332
# 12    326
# 0     299
# 27    290
# 28    288
# 29    274
# 10    261
# 26    257
# 11    252
# 30    226
# 9     221
# 8     215
# 31    194
# 32    191
# 6     176
# 7     163
# 33    162
# 35    128
# 5     125
# 34    122
# 43    120
# 4     111
# 36    106
# 3      99
# 37     87
# 2      81
# 38     79
# 1      78
# 39     66
# 40     55
# 41     36
# 42     35
# Name: count, dtype: int64

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'avg_session_time', 'features_used', 'usage_growth_rate',
#        'last_login_days_ago', 'monthly_fee', 'total_revenue', 'payment_method',
#        'payment_failures', 'discount_applied', 'price_increase_last_3m',
#        'support_tickets', 'avg_resolution_time', 'complaint_type',
#        'csat_score', 'escalations', 'email_open_rate', 'marketing_click_rate',
#        'nps_score', 'survey_response', 'referral_count', 'churn',
#        'tenure_group', 'is_zombie_user'],
#       dtype='object')

# %%
df_clean.weekly_active_days.value_counts()
# Out:
# weekly_active_days
# 0    1322
# 5    1266
# 2    1255
# 6    1254
# 4    1247
# 7    1229
# 1    1221
# 3    1206
# Name: count, dtype: int64

# %%
sns.histplot(df_clean['weekly_active_days'],bins=30,kde=True,color='teal')
# Out:
# <Axes: xlabel='weekly_active_days', ylabel='Count'>

# %%
engagement_corr = df_clean[['monthly_logins', 'weekly_active_days']].corr()

# %%
rho = engagement_corr.loc['monthly_logins', 'weekly_active_days']

# %%
print(f"Correlation (Rho): {rho:.4f}")
# Out:
# Correlation (Rho): 0.0271

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(engagement_corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Engagement Correlation Audit")
plt.show()

# %%
num_features.append('weekly_active_days')

# %%
num_features
# Out:
# ['monthly_logins', 'contract_type', 'is_zombie_user', 'weekly_active_days']

# %%
df_clean['usage_density'] = df_clean['monthly_logins'] / (df_clean['weekly_active_days'] + 1)

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'avg_session_time', 'features_used', 'usage_growth_rate',
#        'last_login_days_ago', 'monthly_fee', 'total_revenue', 'payment_method',
#        'payment_failures', 'discount_applied', 'price_increase_last_3m',
#        'support_tickets', 'avg_resolution_time', 'complaint_type',
#        'csat_score', 'escalations', 'email_open_rate', 'marketing_click_rate',
#        'nps_score', 'survey_response', 'referral_count', 'churn',
#        'tenure_group', 'is_zombie_user', 'usage_density'],
#       dtype='object')

# %%
num_features.append('usage_density')

# %%
num_features
# Out:
# ['monthly_logins',
#  'contract_type',
#  'is_zombie_user',
#  'weekly_active_days',
#  'usage_density']

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'avg_session_time', 'features_used', 'usage_growth_rate',
#        'last_login_days_ago', 'monthly_fee', 'total_revenue', 'payment_method',
#        'payment_failures', 'discount_applied', 'price_increase_last_3m',
#        'support_tickets', 'avg_resolution_time', 'complaint_type',
#        'csat_score', 'escalations', 'email_open_rate', 'marketing_click_rate',
#        'nps_score', 'survey_response', 'referral_count', 'churn',
#        'tenure_group', 'is_zombie_user', 'usage_density'],
#       dtype='object')

# %%
df_clean.weekly_active_days.value_counts()
# Out:
# weekly_active_days
# 0    1322
# 5    1266
# 2    1255
# 6    1254
# 4    1247
# 7    1229
# 1    1221
# 3    1206
# Name: count, dtype: int64

# %%
df_clean.avg_session_time.value_counts()
# Out:
# avg_session_time
# 1.000000     224
# 11.762372      1
# 16.233166      1
# 15.796123      1
# 18.153751      1
#             ...
# 20.858267      1
# 9.890215       1
# 19.716282      1
# 18.606614      1
# 14.793549      1
# Name: count, Length: 9777, dtype: int64

# %%
sns.histplot(df_clean['avg_session_time'],bins=30,kde=True,color='red')
# Out:
# <Axes: xlabel='avg_session_time', ylabel='Count'>

# %%
df_clean['avg_session_time'].max()
# Out:
# 41.99641122063896

# %%
sns.histplot(df_clean['usage_density'],bins=30,kde=True,color='teal')
# Out:
# <Axes: xlabel='usage_density', ylabel='Count'>

# %%
sns.histplot(df_clean['monthly_logins'],bins=30,kde=True,color='yellow')
# Out:
# <Axes: xlabel='monthly_logins', ylabel='Count'>

# %%
df_clean['total_monthly_time'] = df_clean['monthly_logins'] * df_clean['avg_session_time']

# introduced a new feature of total time spent by a user in a month

# %%
num_features.append('total_monthly_time')

# %%
print(df_clean[['monthly_logins', 'avg_session_time', 'total_monthly_time']].head())
# Out:
#    monthly_logins  avg_session_time  total_monthly_time
# 0              26         11.762372          305.821672
# 1               7         26.846390          187.924727
# 2              19         23.380065          444.221234
# 3              34         24.243136          824.266633
# 4              20         18.872323          377.446458

# %%
print(f"\nMax Total Time: {df_clean['total_monthly_time'].max():.2f} minutes")
# Out:
# Max Total Time: 1629.58 minutes

# %%
print(df_clean[['monthly_logins', 'avg_session_time', 'total_monthly_time']].describe())
# Out:
#        monthly_logins  avg_session_time  total_monthly_time
# count    10000.000000      10000.000000        10000.000000
# mean        19.641600         15.187890          298.586162
# std          9.757975          6.830774          210.607572
# min          0.000000          1.000000            0.000000
# 25%         13.000000         10.391645          139.064670
# 50%         20.000000         15.161659          264.590650
# 75%         26.000000         19.882034          421.212798
# max         43.000000         41.996411         1629.576917

# %%
df_clean.avg_session_time.dtype
# Out:
# dtype('float64')

# %%
df_clean['is_bouncer'] = (df_clean['avg_session_time'] <= 2.0).astype(int)

# %%
df_clean.monthly_logins.dtype
# Out:
# dtype('int64')

# %%
num_features.append('is_bouncer')

# %%
cat_features
# Out:
# ['city', 'customer_segment', 'signup_channel', 'tenure_group']

# %%
num_features.append('avg_session_time')

# %%
num_features
# Out:
# ['monthly_logins',
#  'contract_type',
#  'is_zombie_user',
#  'weekly_active_days',
#  'usage_density',
#  'total_monthly_time',
#  'is_bouncer',
#  'avg_session_time']

# %%
df_clean['session_strength'] = df_clean['total_monthly_time'] / (df_clean['weekly_active_days'] + 1)

# %%
num_features.append('session_strength')

# %%
num_features
# Out:
# ['monthly_logins',
#  'contract_type',
#  'is_zombie_user',
#  'weekly_active_days',
#  'usage_density',
#  'total_monthly_time',
#  'is_bouncer',
#  'avg_session_time',
#  'session_strength']

# %%
df_clean.session_strength.value_counts()
# Out:
# session_strength
# 0.000000      299
# 3.000000       10
# 4.000000       10
# 3.500000        6
# 5.000000        6
#              ...
# 20.014904       1
# 42.997098       1
# 46.857697       1
# 86.815826       1
# 110.951615      1
# Name: count, Length: 9599, dtype: int64

# %%
df_clean.session_strength.describe()
# Out:
# count    10000.000000
# mean       102.048990
# std        124.912949
# min          0.000000
# 25%         30.677895
# 50%         62.108853
# 75%        118.406596
# max       1629.576917
# Name: session_strength, dtype: float64

# %%
sns.histplot(df_clean['session_strength'],bins=30,kde=True,color='orange')
# Out:
# <Axes: xlabel='session_strength', ylabel='Count'>

# %%
strength_ceiling = df_clean['session_strength'].quantile(0.99)

# %%
strength_ceiling
# Out:
# np.float64(627.0371541503215)

# %%
df_clean['session_strength'] = df_clean['session_strength'].clip(upper=strength_ceiling)

# %%
sns.histplot(df_clean['session_strength'],bins=30,kde=True,color='orange')
# Out:
# <Axes: xlabel='session_strength', ylabel='Count'>

# %%
df_clean.session_strength.median()
# Out:
# 62.108853495641526

# %%
df_clean['session_strength_log'] = np.log1p(df_clean['session_strength'])

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df_clean['session_strength_log'], kde=True, color='orange')
plt.title("Log-Transformed Session Strength")
plt.show()

# %%
num_features.remove('session_strength')

# %%
num_features
# Out:
# ['monthly_logins',
#  'contract_type',
#  'is_zombie_user',
#  'weekly_active_days',
#  'usage_density',
#  'total_monthly_time',
#  'is_bouncer',
#  'avg_session_time']

# %%
num_features.append('session_strength_log')

# %%
num_features
# Out:
# ['monthly_logins',
#  'contract_type',
#  'is_zombie_user',
#  'weekly_active_days',
#  'usage_density',
#  'total_monthly_time',
#  'is_bouncer',
#  'avg_session_time',
#  'session_strength_log']

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'avg_session_time', 'features_used', 'usage_growth_rate',
#        'last_login_days_ago', 'monthly_fee', 'total_revenue', 'payment_method',
#        'payment_failures', 'discount_applied', 'price_increase_last_3m',
#        'support_tickets', 'avg_resolution_time', 'complaint_type',
#        'csat_score', 'escalations', 'email_open_rate', 'marketing_click_rate',
#        'nps_score', 'survey_response', 'referral_count', 'churn',
#        'tenure_group', 'is_zombie_user', 'usage_density', 'total_monthly_time',
#        'is_bouncer', 'session_strength', 'session_strength_log'],
#       dtype='object')

# %%
df_clean.features_used.value_counts()
# Out:
# features_used
# 4     1767
# 5     1746
# 6     1501
# 3     1394
# 7     1013
# 2      834
# 8      656
# 1      424
# 9      359
# 10     185
# 11      69
# 12      30
# 13      18
# 14       3
# 15       1
# Name: count, dtype: int64

# %%
df_clean.features_used.describe()
# Out:
# count    10000.000000
# mean         4.990800
# std          2.211607
# min          1.000000
# 25%          3.000000
# 50%          5.000000
# 75%          6.000000
# max         15.000000
# Name: features_used, dtype: float64

# %%
df_clean['feature_intensity'] = df_clean['total_monthly_time'] / (df_clean['features_used'] + 1)

# %%
df_clean.feature_intensity.describe()
# Out:
# count    10000.000000
# mean        58.365051
# std         52.843763
# min          0.000000
# 25%         22.753149
# 50%         45.407473
# 75%         78.343635
# max        561.956434
# Name: feature_intensity, dtype: float64

# %%
sns.histplot(df_clean['feature_intensity'],bins=30,kde=True,color='red')
# Out:
# <Axes: xlabel='feature_intensity', ylabel='Count'>

# %%
num_features.extend(['features_used','features_intensity'])

# %%
num_features.remove('features_intensity')

# %%
num_features.append('feature_intensity')

# %%
num_features
# Out:
# ['monthly_logins',
#  'contract_type',
#  'is_zombie_user',
#  'weekly_active_days',
#  'usage_density',
#  'total_monthly_time',
#  'is_bouncer',
#  'avg_session_time',
#  'session_strength_log',
#  'features_used',
#  'feature_intensity']

# %%
intensity_ceiling = df_clean['feature_intensity'].quantile(0.99)

# %%
df_clean['feature_intensity'] = df_clean['feature_intensity'].clip(upper=intensity_ceiling)

# %%
sns.histplot(df_clean['feature_intensity'],bins=30,kde=True,color='red')
# Out:
# <Axes: xlabel='feature_intensity', ylabel='Count'>

# %%
df_clean['feature_intensity_log'] = np.log1p(df_clean['feature_intensity'])

# %%
sns.histplot(df_clean['feature_intensity_log'], kde=True, color='red')
# Out:
# <Axes: xlabel='feature_intensity_log', ylabel='Count'>

# %%
num_features.remove('feature_intensity')

# %%
num_features.append('feature_intensity_log')

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'avg_session_time', 'features_used', 'usage_growth_rate',
#        'last_login_days_ago', 'monthly_fee', 'total_revenue', 'payment_method',
#        'payment_failures', 'discount_applied', 'price_increase_last_3m',
#        'support_tickets', 'avg_resolution_time', 'complaint_type',
#        'csat_score', 'escalations', 'email_open_rate', 'marketing_click_rate',
#        'nps_score', 'survey_response', 'referral_count', 'churn',
#        'tenure_group', 'is_zombie_user', 'usage_density', 'total_monthly_time',
#        'is_bouncer', 'session_strength', 'session_strength_log',
#        'feature_intensity', 'feature_intensity_log'],
#       dtype='object')

# %%
df_clean[df_clean['usage_growth_rate'].describe()].describe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[346], line 1
# ----> 1 df_clean[df_clean['usage_growth_rate'].describe()].describe()
#
# File c:\Users\jaisw\anaconda3\Lib\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\jaisw\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
# ...

# %%
sns.histplot(df_clean['usage_growth_rate'],bins=30,kde=True,color='green')
# Out:
# <Axes: xlabel='usage_growth_rate', ylabel='Count'>

# %%
num_features.append('usage_growth_rate')

# %%
usage_median = df_clean['total_monthly_time'].median()

# %%
df_clean['is_slow_ghost'] = (
    (df_clean['total_monthly_time'] > usage_median) & 
    (df_clean['usage_growth_rate'] < -0.05) & 
    (df_clean['is_zombie_user'] == 0)
).astype(int)

# %%
df_clean.is_slow_ghost.value_counts()
# Out:
# is_slow_ghost
# 0    8414
# 1    1586
# Name: count, dtype: int64

# %%
ghost_count = df_clean['is_slow_ghost'].sum()
print(f"Identified {ghost_count} 'Slow Ghosts' in the dataset.")
# Out:
# Identified 1586 'Slow Ghosts' in the dataset.

# %%
num_features.append('is_slow_ghost')

# %%
num_features
# Out:
# ['monthly_logins',
#  'contract_type',
#  'is_zombie_user',
#  'weekly_active_days',
#  'usage_density',
#  'total_monthly_time',
#  'is_bouncer',
#  'avg_session_time',
#  'session_strength_log',
#  'features_used',
#  'feature_intensity_log',
#  'usage_growth_rate',
#  'is_slow_ghost']

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'avg_session_time', 'features_used', 'usage_growth_rate',
#        'last_login_days_ago', 'monthly_fee', 'total_revenue', 'payment_method',
#        'payment_failures', 'discount_applied', 'price_increase_last_3m',
#        'support_tickets', 'avg_resolution_time', 'complaint_type',
#        'csat_score', 'escalations', 'email_open_rate', 'marketing_click_rate',
#        'nps_score', 'survey_response', 'referral_count', 'churn',
#        'tenure_group', 'is_zombie_user', 'usage_density', 'total_monthly_time',
#        'is_bouncer', 'session_strength', 'session_strength_log',
#        'feature_intensity', 'feature_intensity_log', 'is_slow_ghost'],
#       dtype='object')

# %%
df_clean.last_login_days_ago.value_counts()
# Out:
# last_login_days_ago
# 0     931
# 1     841
# 2     773
# 3     679
# 4     678
#      ...
# 62      1
# 78      1
# 74      1
# 70      1
# 60      1
# Name: count, Length: 71, dtype: int64

# %%
sns.histplot(df_clean['last_login_days_ago'],bins=30,kde=True,color='blue')
# Out:
# <Axes: xlabel='last_login_days_ago', ylabel='Count'>

# %%
df_clean.last_login_days_ago.describe()
# Out:
# count    10000.000000
# mean         9.505200
# std          9.799417
# min          0.000000
# 25%          2.000000
# 50%          6.000000
# 75%         13.000000
# max         80.000000
# Name: last_login_days_ago, dtype: float64

# %%
df_clean['last_login_days_log'] = np.log1p(df_clean['last_login_days_ago'])

# %%
sns.histplot(df_clean['last_login_days_log'],bins=30,kde=True,color='blue')
# Out:
# <Axes: xlabel='last_login_days_log', ylabel='Count'>

# %%
df_clean['is_recency_danger'] = (df_clean['last_login_days_ago'] > 15).astype(int)

# %%
df_clean.is_recency_danger.describe()
# Out:
# count    10000.000000
# mean         0.202200
# std          0.401661
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: is_recency_danger, dtype: float64

# %%
num_features
# Out:
# ['monthly_logins',
#  'contract_type',
#  'is_zombie_user',
#  'weekly_active_days',
#  'usage_density',
#  'total_monthly_time',
#  'is_bouncer',
#  'avg_session_time',
#  'session_strength_log',
#  'features_used',
#  'feature_intensity_log',
#  'usage_growth_rate',
#  'is_slow_ghost']

# %%
df_clean.drop(columns=['last_login_days_ago'],inplace=True)

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'avg_session_time', 'features_used', 'usage_growth_rate', 'monthly_fee',
#        'total_revenue', 'payment_method', 'payment_failures',
#        'discount_applied', 'price_increase_last_3m', 'support_tickets',
#        'avg_resolution_time', 'complaint_type', 'csat_score', 'escalations',
#        'email_open_rate', 'marketing_click_rate', 'nps_score',
#        'survey_response', 'referral_count', 'churn', 'tenure_group',
#        'is_zombie_user', 'usage_density', 'total_monthly_time', 'is_bouncer',
#        'session_strength', 'session_strength_log', 'feature_intensity',
#        'feature_intensity_log', 'is_slow_ghost', 'last_login_days_log',
#        'is_recency_danger'],
#       dtype='object')

# %%
num_features.extend(['last_login_days_log','is_recency_danger'])

# %%
num_features
# Out:
# ['monthly_logins',
#  'contract_type',
#  'is_zombie_user',
#  'weekly_active_days',
#  'usage_density',
#  'total_monthly_time',
#  'is_bouncer',
#  'avg_session_time',
#  'session_strength_log',
#  'features_used',
#  'feature_intensity_log',
#  'usage_growth_rate',
#  'is_slow_ghost',
#  'last_login_days_log',
#  'last_login_days_log',
#  'is_recency_danger']

# %%
cat_features
# Out:
# ['city', 'customer_segment', 'signup_channel', 'tenure_group']

# %%
cols_to_drop = ['last_login_days_ago', 'session_strength', 'feature_intensity']
df_final = df_clean.drop(columns=[c for c in cols_to_drop if c in df_clean.columns],inplace=True)

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'avg_session_time', 'features_used', 'usage_growth_rate', 'monthly_fee',
#        'total_revenue', 'payment_method', 'payment_failures',
#        'discount_applied', 'price_increase_last_3m', 'support_tickets',
#        'avg_resolution_time', 'complaint_type', 'csat_score', 'escalations',
#        'email_open_rate', 'marketing_click_rate', 'nps_score',
#        'survey_response', 'referral_count', 'churn', 'tenure_group',
#        'is_zombie_user', 'usage_density', 'total_monthly_time', 'is_bouncer',
#        'session_strength_log', 'feature_intensity_log', 'is_slow_ghost',
#        'last_login_days_log', 'is_recency_danger'],
#       dtype='object')

# %%
df_clean.drop(columns=['avg_session_time'],inplace=True)

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'features_used', 'usage_growth_rate', 'monthly_fee', 'total_revenue',
#        'payment_method', 'payment_failures', 'discount_applied',
#        'price_increase_last_3m', 'support_tickets', 'avg_resolution_time',
#        'complaint_type', 'csat_score', 'escalations', 'email_open_rate',
#        'marketing_click_rate', 'nps_score', 'survey_response',
#        'referral_count', 'churn', 'tenure_group', 'is_zombie_user',
#        'usage_density', 'total_monthly_time', 'is_bouncer',
#        'session_strength_log', 'feature_intensity_log', 'is_slow_ghost',
#        'last_login_days_log', 'is_recency_danger'],
#       dtype='object')

# %%
df_clean.monthly_fee.value_counts()
# Out:
# monthly_fee
# 20     2565
# 30     1996
# 50     1990
# 10     1970
# 70      966
# 100     513
# Name: count, dtype: int64

# %%
df_clean.monthly_fee.describe()
# Out:
# count    10000.000000
# mean        34.930000
# std         23.785115
# min         10.000000
# 25%         20.000000
# 50%         30.000000
# 75%         50.000000
# max        100.000000
# Name: monthly_fee, dtype: float64

# %%
sns.histplot(df_clean['monthly_fee'],bins=10,kde=True,color='green')
# Out:
# <Axes: xlabel='monthly_fee', ylabel='Count'>

# %%
df_clean['monthly_fee_log'] = np.log1p(df_clean['monthly_fee'])

# %%
sns.histplot(df_clean['monthly_fee_log'],bins=10,kde=True,color='green')
# Out:
# <Axes: xlabel='monthly_fee_log', ylabel='Count'>

# %%
num_features.append(['monthly_fee_log'])

# %%
df_clean.drop(columns=['monthly_fee'],inplace=True)

# %%
df_clean['value_score'] = df_clean['total_monthly_time'] / np.exp(df_clean['monthly_fee_log'])

# %%
num_features.append('value_score')

# %%
sns.histplot(df_clean['value_score'],bins=30,kde=True,color='teal')
# Out:
# <Axes: xlabel='value_score', ylabel='Count'>

# %%
value_ceiling = df_clean['value_score'].quantile(0.99)
df_clean['value_score'] = df_clean['value_score'].clip(upper=value_ceiling)

# %%
df_clean['value_score_log'] = np.log1p(df_clean['value_score'])

# %%
sns.histplot(df_clean['value_score_log'], kde=True, color='teal')
# Out:
# <Axes: xlabel='value_score_log', ylabel='Count'>

# %%
num_features.remove('value_score')

# %%
num_features.append('value_score_log')

# %%
df_clean.drop(columns=['value_score'],inplace=True)

# %%
num_features
# Out:
# ['monthly_logins',
#  'contract_type',
#  'is_zombie_user',
#  'weekly_active_days',
#  'usage_density',
#  'total_monthly_time',
#  'is_bouncer',
#  'avg_session_time',
#  'session_strength_log',
#  'features_used',
#  'feature_intensity_log',
#  'usage_growth_rate',
#  'is_slow_ghost',
#  'last_login_days_log',
#  'last_login_days_log',
#  'is_recency_danger',
#  ['monthly_fee_log'],
#  'value_score_log']

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'features_used', 'usage_growth_rate', 'total_revenue', 'payment_method',
#        'payment_failures', 'discount_applied', 'price_increase_last_3m',
#        'support_tickets', 'avg_resolution_time', 'complaint_type',
#        'csat_score', 'escalations', 'email_open_rate', 'marketing_click_rate',
#        'nps_score', 'survey_response', 'referral_count', 'churn',
#        'tenure_group', 'is_zombie_user', 'usage_density', 'total_monthly_time',
#        'is_bouncer', 'session_strength_log', 'feature_intensity_log',
#        'is_slow_ghost', 'last_login_days_log', 'is_recency_danger',
#        'monthly_fee_log', 'value_score_log'],
#       dtype='object')

# %%
df_clean.tenure_group.value_counts()
# Out:
# tenure_group
# Established    4036
# Loyal          3914
# New            2050
# Name: count, dtype: int64

# %%
df_clean.total_revenue.value_counts()
# Out:
# total_revenue
# 300     157
# 200     132
# 420     128
# 360     127
# 480     121
#        ...
# 5000      6
# 4000      6
# 5600      5
# 3200      4
# 5500      3
# Name: count, Length: 221, dtype: int64

# %%
df_clean.total_revenue.describe()
# Out:
# count    10000.000000
# mean      1057.018000
# std       1020.148233
# min         10.000000
# 25%        340.000000
# 50%        720.000000
# 75%       1440.000000
# max       5900.000000
# Name: total_revenue, dtype: float64

# %%
sns.histplot(df_clean['total_revenue'],bins=30,kde=True,color='orange')
# Out:
# <Axes: xlabel='total_revenue', ylabel='Count'>

# %%
df_clean.drop(columns=['total_revenue'],inplace=True)

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'features_used', 'usage_growth_rate', 'payment_method',
#        'payment_failures', 'discount_applied', 'price_increase_last_3m',
#        'support_tickets', 'avg_resolution_time', 'complaint_type',
#        'csat_score', 'escalations', 'email_open_rate', 'marketing_click_rate',
#        'nps_score', 'survey_response', 'referral_count', 'churn',
#        'tenure_group', 'is_zombie_user', 'usage_density', 'total_monthly_time',
#        'is_bouncer', 'session_strength_log', 'feature_intensity_log',
#        'is_slow_ghost', 'last_login_days_log', 'is_recency_danger',
#        'monthly_fee_log', 'value_score_log'],
#       dtype='object')

# %%
df_clean.payment_method.value_counts()
# Out:
# payment_method
# Card             5955
# PayPal           2557
# Bank Transfer    1488
# Name: count, dtype: int64

# %%
df_clean.payment_failures.value_counts()
# Out:
# payment_failures
# 0    6084
# 1    2989
# 2     780
# 3     130
# 4      14
# 5       3
# Name: count, dtype: int64

# %%
sns.histplot(df_clean['payment_method'],bins=30,kde=True,color='blue')
# Out:
# <Axes: xlabel='payment_method', ylabel='Count'>

# %%
sns.histplot(df_clean['payment_failures'],bins=5,kde=True,color='blue')
# Out:
# <Axes: xlabel='payment_failures', ylabel='Count'>

# %%
df_clean['payment_failures_clipped'] = df_clean['payment_failures'].clip(upper=3)

# %%
sns.histplot(df_clean['payment_failures_clipped'],bins=5,kde=True,color='blue')
# Out:
# <Axes: xlabel='payment_failures_clipped', ylabel='Count'>

# %%
num_features.append('payment_failures_clipped')

# %%
df_clean.drop(columns=['payment_failures'],inplace=True)

# %%
df_clean['is_high_friction_payment'] = df_clean['payment_method'].isin(['Bank Transfer', 'PayPal']).astype(int)

df_clean['payment_structural_risk'] = df_clean['is_high_friction_payment'] * df_clean['payment_failures_clipped']

# %%
df_clean.is_high_friction_payment.value_counts()
# Out:
# is_high_friction_payment
# 0    5955
# 1    4045
# Name: count, dtype: int64

# %%
df_clean.payment_structural_risk.value_counts()
# Out:
# payment_structural_risk
# 0    8414
# 1    1198
# 2     327
# 3      61
# Name: count, dtype: int64

# %%
num_features.extend(['is_high_friction_payment','payment_structural_risk'])

# %%
df_clean.head()
# Out:
#    gender  age      city customer_segment signup_channel  contract_type  \
# 0    Male   68    London              SME            Web              1
# 1  Female   57    Sydney       Individual         Mobile              1
# 2    Male   24  New York              SME            Web              3
# 3    Male   49     Dhaka       Individual         Mobile              3
# 4    Male   65     Delhi       Individual            Web              1
#
#    monthly_logins  weekly_active_days  features_used  usage_growth_rate  ...  \
# 0              26                   7              5               0.06  ...
# 1               7                   5              1              -0.28  ...
# 2              19                   5              6               0.13  ...
# 3              34                   7              2              -0.17  ...
# 4              20                   6              2              -0.16  ...
#
#   session_strength_log feature_intensity_log is_slow_ghost  \
# ...

# %%
sns.histplot(df_clean['is_high_friction_payment'],bins=30,kde=True,color='teal')
# Out:
# <Axes: xlabel='is_high_friction_payment', ylabel='Count'>

# %%
sns.histplot(df_clean['payment_structural_risk'],bins=5,kde=True,color='teal')
# Out:
# <Axes: xlabel='payment_structural_risk', ylabel='Count'>

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'features_used', 'usage_growth_rate', 'payment_method',
#        'discount_applied', 'price_increase_last_3m', 'support_tickets',
#        'avg_resolution_time', 'complaint_type', 'csat_score', 'escalations',
#        'email_open_rate', 'marketing_click_rate', 'nps_score',
#        'survey_response', 'referral_count', 'churn', 'tenure_group',
#        'is_zombie_user', 'usage_density', 'total_monthly_time', 'is_bouncer',
#        'session_strength_log', 'feature_intensity_log', 'is_slow_ghost',
#        'last_login_days_log', 'is_recency_danger', 'monthly_fee_log',
#        'value_score_log', 'payment_failures_clipped',
#        'is_high_friction_payment', 'payment_structural_risk'],
#       dtype='object')

# %%
cat_features.append('payment_method')

# %%
df_clean.discount_applied.describe()
# Out:
# count     10000
# unique        2
# top          No
# freq       6950
# Name: discount_applied, dtype: object

# %%
sns.histplot(df_clean['discount_applied'],bins=10,kde=True,color='blue')
# Out:
# <Axes: xlabel='discount_applied', ylabel='Count'>

# %%
df_clean['discount_applied'] = df_clean['discount_applied'].map({'Yes': 1, 'No': 0})

# %%
sns.barplot(y=df_clean['discount_applied'])
# Out:
# <Axes: ylabel='discount_applied'>

# %%
churn_by_discount = pd.crosstab(df_clean['discount_applied'], df_clean['churn'], normalize='index') * 100
print("Churn % by Discount Status:\n", churn_by_discount)
# Out:
# Churn % by Discount Status:
#  churn                     0          1
# discount_applied
# 0                 89.525180  10.474820
# 1                 90.393443   9.606557

# %%
plt.figure(figsize=(8, 5))
sns.heatmap(pd.crosstab(df_clean['discount_applied'], df_clean['churn']), annot=True, fmt='d', cmap='YlGnBu')
plt.title("Discount vs. Churn Count")
plt.show()

# %%
# Compare Value Score across Discount Groups
value_audit = df_clean.groupby('discount_applied')['value_score_log'].agg(['mean', 'median', 'std'])
print("Value Score Audit:\n", value_audit)

# Boxplot to see the distribution shift
plt.figure(figsize=(8, 5))
sns.boxplot(x='discount_applied', y='value_score_log', data=df_clean, palette='Set2')
plt.title("Perceived Value: Discounted vs. Full Price")
plt.show()
# Out:
# Value Score Audit:
#                        mean    median       std
# discount_applied
# 0                 2.184296  2.229695  0.967083
# 1                 2.194223  2.257123  0.971545
# C:\Users\jaisw\AppData\Local\Temp\ipykernel_14864\2893699001.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='discount_applied', y='value_score_log', data=df_clean, palette='Set2')

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'features_used', 'usage_growth_rate', 'payment_method',
#        'discount_applied', 'price_increase_last_3m', 'support_tickets',
#        'avg_resolution_time', 'complaint_type', 'csat_score', 'escalations',
#        'email_open_rate', 'marketing_click_rate', 'nps_score',
#        'survey_response', 'referral_count', 'churn', 'tenure_group',
#        'is_zombie_user', 'usage_density', 'total_monthly_time', 'is_bouncer',
#        'session_strength_log', 'feature_intensity_log', 'is_slow_ghost',
#        'last_login_days_log', 'is_recency_danger', 'monthly_fee_log',
#        'value_score_log', 'payment_failures_clipped',
#        'is_high_friction_payment', 'payment_structural_risk'],
#       dtype='object')

# %%
num_features
# Out:
# ['monthly_logins',
#  'contract_type',
#  'is_zombie_user',
#  'weekly_active_days',
#  'usage_density',
#  'total_monthly_time',
#  'is_bouncer',
#  'avg_session_time',
#  'session_strength_log',
#  'features_used',
#  'feature_intensity_log',
#  'usage_growth_rate',
#  'is_slow_ghost',
#  'last_login_days_log',
#  'last_login_days_log',
#  'is_recency_danger',
#  ['monthly_fee_log'],
#  'value_score_log',
#  'payment_failures_clipped',
#  'is_high_friction_payment',
#  'payment_structural_risk']

# %%
num_features.remove( ['monthly_fee_log'])

# %%
num_features.extend(['monthly_fee_log','discount_applied'])

# %%
num_features
# Out:
# ['monthly_logins',
#  'contract_type',
#  'is_zombie_user',
#  'weekly_active_days',
#  'usage_density',
#  'total_monthly_time',
#  'is_bouncer',
#  'avg_session_time',
#  'session_strength_log',
#  'features_used',
#  'feature_intensity_log',
#  'usage_growth_rate',
#  'is_slow_ghost',
#  'last_login_days_log',
#  'last_login_days_log',
#  'is_recency_danger',
#  'value_score_log',
#  'payment_failures_clipped',
#  'is_high_friction_payment',
#  'payment_structural_risk',
#  'monthly_fee_log',
#  'discount_applied']

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'features_used', 'usage_growth_rate', 'payment_method',
#        'discount_applied', 'price_increase_last_3m', 'support_tickets',
#        'avg_resolution_time', 'complaint_type', 'csat_score', 'escalations',
#        'email_open_rate', 'marketing_click_rate', 'nps_score',
#        'survey_response', 'referral_count', 'churn', 'tenure_group',
#        'is_zombie_user', 'usage_density', 'total_monthly_time', 'is_bouncer',
#        'session_strength_log', 'feature_intensity_log', 'is_slow_ghost',
#        'last_login_days_log', 'is_recency_danger', 'monthly_fee_log',
#        'value_score_log', 'payment_failures_clipped',
#        'is_high_friction_payment', 'payment_structural_risk'],
#       dtype='object')

# %%
df_clean.price_increase_last_3m.value_counts()
# Out:
# price_increase_last_3m
# No     8055
# Yes    1945
# Name: count, dtype: int64

# %%
df_clean['price_increase_last_3m'] = df_clean['price_increase_last_3m'].map({'Yes': 1, 'No': 0})

# %%
print("Tenure Groups:", df_clean['tenure_group'].unique())
# Out:
# Tenure Groups: ['Established', 'New', 'Loyal']
# Categories (3, object): ['New' < 'Established' < 'Loyal']

# %%
tenure_weight_map = {
    '0-6 months': 4,
    '6-12 months': 3,
    '1-2 years': 2,
    'Over 2 years': 1
}

# %%
df_clean['tenure_risk_weight'] = df_clean['tenure_group'].map(tenure_weight_map)
df_clean['loyalty_shock_score'] = df_clean['tenure_risk_weight'] * df_clean['price_increase_last_3m']

# %%
df_clean = df_clean.drop(columns=['tenure_risk_weight'])

# %%
num_features.append('loyalty_shock_score')

# %%
num_features
# Out:
# ['monthly_logins',
#  'contract_type',
#  'is_zombie_user',
#  'weekly_active_days',
#  'usage_density',
#  'total_monthly_time',
#  'is_bouncer',
#  'avg_session_time',
#  'session_strength_log',
#  'features_used',
#  'feature_intensity_log',
#  'usage_growth_rate',
#  'is_slow_ghost',
#  'last_login_days_log',
#  'last_login_days_log',
#  'is_recency_danger',
#  'value_score_log',
#  'payment_failures_clipped',
#  'is_high_friction_payment',
#  'payment_structural_risk',
#  'monthly_fee_log',
#  'discount_applied',
#  'loyalty_shock_score']

# %%
df_clean.drop(columns=['price_increase_last_3m'], errors='ignore',inplace=True)

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'features_used', 'usage_growth_rate', 'payment_method',
#        'discount_applied', 'support_tickets', 'avg_resolution_time',
#        'complaint_type', 'csat_score', 'escalations', 'email_open_rate',
#        'marketing_click_rate', 'nps_score', 'survey_response',
#        'referral_count', 'churn', 'tenure_group', 'is_zombie_user',
#        'usage_density', 'total_monthly_time', 'is_bouncer',
#        'session_strength_log', 'feature_intensity_log', 'is_slow_ghost',
#        'last_login_days_log', 'is_recency_danger', 'monthly_fee_log',
#        'value_score_log', 'payment_failures_clipped',
#        'is_high_friction_payment', 'payment_structural_risk',
#        'loyalty_shock_score'],
#       dtype='object')

# %%
df_clean.support_tickets.value_counts()
# Out:
# support_tickets
# 1    3609
# 0    3012
# 2    2124
# 3     908
# 4     273
# 5      56
# 6      13
# 7       5
# Name: count, dtype: int64

# %%
sns.histplot(df_clean['support_tickets'],bins=30,kde=True,color='blue')
# Out:
# <Axes: xlabel='support_tickets', ylabel='Count'>

# %%
df_clean['support_tickets_clipped'] = df_clean['support_tickets'].clip(upper=4)

# %%
df_clean['support_intensity_score'] = df_clean['support_tickets_clipped'] * df_clean['avg_resolution_time']

# %%
df_clean['support_intensity_log'] = np.log1p(df_clean['support_intensity_score'])

# %%
df_clean['support_intensity_log'] = df_clean['support_intensity_log'].fillna(0)

# %%
for f in ['support_tickets_clipped', 'support_intensity_log']:
    if f not in num_features:
        num_features.append(f)

# %%
num_features
# Out:
# ['monthly_logins',
#  'contract_type',
#  'is_zombie_user',
#  'weekly_active_days',
#  'usage_density',
#  'total_monthly_time',
#  'is_bouncer',
#  'avg_session_time',
#  'session_strength_log',
#  'features_used',
#  'feature_intensity_log',
#  'usage_growth_rate',
#  'is_slow_ghost',
#  'last_login_days_log',
#  'last_login_days_log',
#  'is_recency_danger',
#  'value_score_log',
#  'payment_failures_clipped',
#  'is_high_friction_payment',
#  'payment_structural_risk',
#  'monthly_fee_log',
#  'discount_applied',
#  'loyalty_shock_score',
#  'support_tickets_clipped',
#  'support_intensity_log']

# %%
df_clean.avg_resolution_time.describe()
# Out:
# count    10000.000000
# mean        23.953210
# std          9.956999
# min          1.000000
# 25%         17.082041
# 50%         23.950444
# 75%         30.758480
# max         61.821878
# Name: avg_resolution_time, dtype: float64

# %%
df_clean.avg_resolution_time.value_counts()
# Out:
# avg_resolution_time
# 1.000000     118
# 13.354360      1
# 25.258834      1
# 16.134199      1
# 35.081840      1
#             ...
# 21.298596      1
# 30.476408      1
# 31.553545      1
# 24.513059      1
# 23.536914      1
# Name: count, Length: 9883, dtype: int64

# %%
sns.histplot(df_clean['avg_resolution_time'],bins=30,kde=True,color='red')
# Out:
# <Axes: xlabel='avg_resolution_time', ylabel='Count'>

# %%
cols_to_drop = ['support_tickets', 'avg_resolution_time']
df_clean.drop(columns=[c for c in cols_to_drop if c in df_clean.columns],inplace=True)

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'avg_session_time', 'features_used', 'usage_growth_rate',
#        'last_login_days_ago', 'monthly_fee', 'total_revenue', 'payment_method',
#        'payment_failures', 'discount_applied', 'price_increase_last_3m',
#        'complaint_type', 'csat_score', 'escalations', 'email_open_rate',
#        'marketing_click_rate', 'nps_score', 'survey_response',
#        'referral_count', 'churn', 'tenure_group', 'is_zombie_user',
#        'usage_density', 'total_monthly_time', 'is_bouncer', 'session_strength',
#        'session_strength_log', 'feature_intensity', 'feature_intensity_log'],
#       dtype='object')

# %%
import numpy as np


tenure_weight_map = {
    'New': 4,           
    'Established': 2,   
    'Loyal': 1
}
usage_median = df_clean['total_monthly_time'].median()


df_clean['is_slow_ghost'] = (
    (df_clean['total_monthly_time'] > usage_median) & 
    (df_clean['usage_growth_rate'] < -0.05) & 
    (df_clean['is_zombie_user'] == 0)
).astype(int)


df_clean['last_login_days_log'] = np.log1p(df_clean['last_login_days_ago'])
df_clean['is_recency_danger'] = (df_clean['last_login_days_ago'] > 15).astype(int)

df_clean['monthly_fee_log'] = np.log1p(df_clean['monthly_fee'])

df_clean['value_score'] = df_clean['total_monthly_time'] / (df_clean['monthly_fee'] + 1)
df_clean['value_score_log'] = np.log1p(df_clean['value_score'].clip(upper=df_clean['value_score'].quantile(0.99)))



df_clean['payment_failures_clipped'] = df_clean['payment_failures'].clip(upper=3)
df_clean['is_high_friction_payment'] = df_clean['payment_method'].isin(['Bank Transfer', 'PayPal']).astype(int)
df_clean['payment_structural_risk'] = df_clean['is_high_friction_payment'] * df_clean['payment_failures_clipped']



df_clean['discount_applied'] = df_clean['discount_applied'].map({'Yes': 1, 'No': 0, 1: 1, 0: 0})
df_clean['price_increase_last_3m_bin'] = df_clean['price_increase_last_3m'].map({'Yes': 1, 'No': 0, 1: 1, 0: 0})
df_clean['loyalty_shock_score'] = df_clean['tenure_group'].map(tenure_weight_map).astype(float) * df_clean['price_increase_last_3m_bin']


df_clean['support_tickets_clipped'] = df_clean['support_tickets'].clip(upper=4)
df_clean['support_intensity_log'] = np.log1p(df_clean['support_tickets_clipped'] * df_clean['avg_resolution_time'])


num_features = [
    'monthly_logins', 'weekly_active_days', 'usage_density', 'total_monthly_time',
    'session_strength_log', 'features_used', 'feature_intensity_log', 
    'usage_growth_rate', 'is_slow_ghost', 'last_login_days_log', 'is_recency_danger',
    'monthly_fee_log', 'value_score_log', 'payment_failures_clipped', 
    'is_high_friction_payment', 'payment_structural_risk', 'loyalty_shock_score',
    'support_tickets_clipped', 'support_intensity_log', 'discount_applied',
    'is_zombie_user', 'is_bouncer'
]

cat_features = ['city', 'signup_channel', 'payment_method', 'tenure_group', 'complaint_type']

cols_to_drop = [
    'last_login_days_ago', 'monthly_fee', 'value_score', 'payment_failures',
    'price_increase_last_3m', 'price_increase_last_3m_bin', 'support_tickets', 
    'avg_resolution_time', 'total_revenue', 'avg_session_time', 'session_strength', 'feature_intensity'
]
df_final = df_clean.drop(columns=[c for c in cols_to_drop if c in df_clean.columns])

print(f"Engineized Dataframe Ready. Shape: {df_final.shape}")
print(f"Numerical Features: {len(num_features)}")
print(f"Categorical Features: {len(cat_features)}")
# Out:
# Engineized Dataframe Ready. Shape: (10000, 39)
# Numerical Features: 22
# Categorical Features: 5

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'avg_session_time', 'features_used', 'usage_growth_rate',
#        'last_login_days_ago', 'monthly_fee', 'total_revenue', 'payment_method',
#        'payment_failures', 'discount_applied', 'price_increase_last_3m',
#        'support_tickets', 'avg_resolution_time', 'complaint_type',
#        'csat_score', 'escalations', 'email_open_rate', 'marketing_click_rate',
#        'nps_score', 'survey_response', 'referral_count', 'churn',
#        'tenure_group', 'is_zombie_user', 'usage_density', 'total_monthly_time',
#        'is_bouncer', 'session_strength', 'session_strength_log',
#        'feature_intensity', 'feature_intensity_log', 'is_slow_ghost',
#        'last_login_days_log', 'is_recency_danger', 'monthly_fee_log',
#        'value_score', 'value_score_log', 'payment_failures_clipped',
# ...

# %%
df_clean.drop(columns=['avg_session_time','last_login_days_ago', 'monthly_fee', 'total_revenue'],inplace=True)

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'features_used', 'usage_growth_rate', 'payment_method',
#        'payment_failures', 'discount_applied', 'price_increase_last_3m',
#        'support_tickets', 'avg_resolution_time', 'complaint_type',
#        'csat_score', 'escalations', 'email_open_rate', 'marketing_click_rate',
#        'nps_score', 'survey_response', 'referral_count', 'churn',
#        'tenure_group', 'is_zombie_user', 'usage_density', 'total_monthly_time',
#        'is_bouncer', 'session_strength', 'session_strength_log',
#        'feature_intensity', 'feature_intensity_log', 'is_slow_ghost',
#        'last_login_days_log', 'is_recency_danger', 'monthly_fee_log',
#        'value_score', 'value_score_log', 'payment_failures_clipped',
#        'is_high_friction_payment', 'payment_structural_risk',
#        'price_increase_last_3m_bin', 'loyalty_shock_score',
# ...

# %%
df_clean.drop(columns=['payment_failures','price_increase_last_3m'],inplace=True)

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'features_used', 'usage_growth_rate', 'payment_method',
#        'discount_applied', 'support_tickets', 'avg_resolution_time',
#        'complaint_type', 'csat_score', 'escalations', 'email_open_rate',
#        'marketing_click_rate', 'nps_score', 'survey_response',
#        'referral_count', 'churn', 'tenure_group', 'is_zombie_user',
#        'usage_density', 'total_monthly_time', 'is_bouncer', 'session_strength',
#        'session_strength_log', 'feature_intensity', 'feature_intensity_log',
#        'is_slow_ghost', 'last_login_days_log', 'is_recency_danger',
#        'monthly_fee_log', 'value_score', 'value_score_log',
#        'payment_failures_clipped', 'is_high_friction_payment',
#        'payment_structural_risk', 'price_increase_last_3m_bin',
#        'loyalty_shock_score', 'support_tickets_clipped',
# ...

# %%
df_clean.drop(columns=['session_strength'],inplace=True)

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'features_used', 'usage_growth_rate', 'payment_method',
#        'discount_applied', 'support_tickets', 'avg_resolution_time',
#        'complaint_type', 'csat_score', 'escalations', 'email_open_rate',
#        'marketing_click_rate', 'nps_score', 'survey_response',
#        'referral_count', 'churn', 'tenure_group', 'is_zombie_user',
#        'usage_density', 'total_monthly_time', 'is_bouncer',
#        'session_strength_log', 'feature_intensity', 'feature_intensity_log',
#        'is_slow_ghost', 'last_login_days_log', 'is_recency_danger',
#        'monthly_fee_log', 'value_score', 'value_score_log',
#        'payment_failures_clipped', 'is_high_friction_payment',
#        'payment_structural_risk', 'price_increase_last_3m_bin',
#        'loyalty_shock_score', 'support_tickets_clipped',
#        'support_intensity_log'],
# ...

# %%
df_clean.drop(columns=['feature_intensity'],inplace=True)

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'features_used', 'usage_growth_rate', 'payment_method',
#        'discount_applied', 'support_tickets', 'avg_resolution_time',
#        'complaint_type', 'csat_score', 'escalations', 'email_open_rate',
#        'marketing_click_rate', 'nps_score', 'survey_response',
#        'referral_count', 'churn', 'tenure_group', 'is_zombie_user',
#        'usage_density', 'total_monthly_time', 'is_bouncer',
#        'session_strength_log', 'feature_intensity_log', 'is_slow_ghost',
#        'last_login_days_log', 'is_recency_danger', 'monthly_fee_log',
#        'value_score', 'value_score_log', 'payment_failures_clipped',
#        'is_high_friction_payment', 'payment_structural_risk',
#        'price_increase_last_3m_bin', 'loyalty_shock_score',
#        'support_tickets_clipped', 'support_intensity_log'],
#       dtype='object')

# %%
df_clean.drop(columns=['value_score'],inplace=True)

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'features_used', 'usage_growth_rate', 'payment_method',
#        'discount_applied', 'support_tickets', 'avg_resolution_time',
#        'complaint_type', 'csat_score', 'escalations', 'email_open_rate',
#        'marketing_click_rate', 'nps_score', 'survey_response',
#        'referral_count', 'churn', 'tenure_group', 'is_zombie_user',
#        'usage_density', 'total_monthly_time', 'is_bouncer',
#        'session_strength_log', 'feature_intensity_log', 'is_slow_ghost',
#        'last_login_days_log', 'is_recency_danger', 'monthly_fee_log',
#        'value_score_log', 'payment_failures_clipped',
#        'is_high_friction_payment', 'payment_structural_risk',
#        'price_increase_last_3m_bin', 'loyalty_shock_score',
#        'support_tickets_clipped', 'support_intensity_log'],
#       dtype='object')

# %%
df_clean.drop(columns=[ 'price_increase_last_3m_bin',  'support_tickets_clipped', 'support_intensity_log'],inplace=True)

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'features_used', 'usage_growth_rate', 'payment_method',
#        'discount_applied', 'support_tickets', 'avg_resolution_time',
#        'complaint_type', 'csat_score', 'escalations', 'email_open_rate',
#        'marketing_click_rate', 'nps_score', 'survey_response',
#        'referral_count', 'churn', 'tenure_group', 'is_zombie_user',
#        'usage_density', 'total_monthly_time', 'is_bouncer',
#        'session_strength_log', 'feature_intensity_log', 'is_slow_ghost',
#        'last_login_days_log', 'is_recency_danger', 'monthly_fee_log',
#        'value_score_log', 'payment_failures_clipped',
#        'is_high_friction_payment', 'payment_structural_risk',
#        'loyalty_shock_score'],
#       dtype='object')

# %%
sns.histplot(df_clean['last_login_days_log'],bins=30,kde=True,color='red')
# Out:
# <Axes: xlabel='last_login_days_log', ylabel='Count'>

# %%
df_clean.support_tickets.describe()
# Out:
# count    10000.000000
# mean         1.206600
# std          1.104554
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          2.000000
# max          7.000000
# Name: support_tickets, dtype: float64

# %%
df_clean['support_tickets_clipped'] = df_clean['support_tickets'].clip(upper=4)

# %%
df_clean['support_intensity_log'] = np.log1p(df_clean['support_tickets_clipped'] * df_clean['avg_resolution_time'])

# %%
df_clean.drop(columns=['support_tickets'],inplace=True)

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'features_used', 'usage_growth_rate', 'payment_method',
#        'discount_applied', 'avg_resolution_time', 'complaint_type',
#        'csat_score', 'escalations', 'email_open_rate', 'marketing_click_rate',
#        'nps_score', 'survey_response', 'referral_count', 'churn',
#        'tenure_group', 'is_zombie_user', 'usage_density', 'total_monthly_time',
#        'is_bouncer', 'session_strength_log', 'feature_intensity_log',
#        'is_slow_ghost', 'last_login_days_log', 'is_recency_danger',
#        'monthly_fee_log', 'value_score_log', 'payment_failures_clipped',
#        'is_high_friction_payment', 'payment_structural_risk',
#        'loyalty_shock_score', 'support_tickets_clipped',
#        'support_intensity_log'],
#       dtype='object')

# %%
num_features
# Out:
# ['monthly_logins',
#  'weekly_active_days',
#  'usage_density',
#  'total_monthly_time',
#  'session_strength_log',
#  'features_used',
#  'feature_intensity_log',
#  'usage_growth_rate',
#  'is_slow_ghost',
#  'last_login_days_log',
#  'is_recency_danger',
#  'monthly_fee_log',
#  'value_score_log',
#  'payment_failures_clipped',
#  'is_high_friction_payment',
#  'payment_structural_risk',
#  'loyalty_shock_score',
#  'support_tickets_clipped',
#  'support_intensity_log',
#  'discount_applied',
#  'is_zombie_user',
#  'is_bouncer']

# %%
df_clean.drop(columns=['support_tickets_clipped'],inplace=True)

# %%
num_features.remove('support_tickets_clipped')

# %%
num_features
# Out:
# ['monthly_logins',
#  'weekly_active_days',
#  'usage_density',
#  'total_monthly_time',
#  'session_strength_log',
#  'features_used',
#  'feature_intensity_log',
#  'usage_growth_rate',
#  'is_slow_ghost',
#  'last_login_days_log',
#  'is_recency_danger',
#  'monthly_fee_log',
#  'value_score_log',
#  'payment_failures_clipped',
#  'is_high_friction_payment',
#  'payment_structural_risk',
#  'loyalty_shock_score',
#  'support_intensity_log',
#  'discount_applied',
#  'is_zombie_user',
#  'is_bouncer']

# %%
df_clean['support_tickets'] = df_raw['support_tickets']

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'features_used', 'usage_growth_rate', 'payment_method',
#        'discount_applied', 'avg_resolution_time', 'complaint_type',
#        'csat_score', 'escalations', 'email_open_rate', 'marketing_click_rate',
#        'nps_score', 'survey_response', 'referral_count', 'churn',
#        'tenure_group', 'is_zombie_user', 'usage_density', 'total_monthly_time',
#        'is_bouncer', 'session_strength_log', 'feature_intensity_log',
#        'is_slow_ghost', 'last_login_days_log', 'is_recency_danger',
#        'monthly_fee_log', 'value_score_log', 'payment_failures_clipped',
#        'is_high_friction_payment', 'payment_structural_risk',
#        'loyalty_shock_score', 'support_intensity_log', 'support_tickets'],
#       dtype='object')

# %%
df_clean['support_tickets_clipped'] = df_clean['support_tickets'].clip(upper=4)

# %%
df_clean['support_intensity_log'] = np.log1p(df_clean['support_tickets_clipped'] * df_clean['avg_resolution_time'])

# %%
for f in ['support_tickets_clipped', 'support_intensity_log']:
    if f not in num_features:
        num_features.append(f)

# %%
df_clean.drop(columns=['support_tickets', 'avg_resolution_time'],inplace=True)

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'features_used', 'usage_growth_rate', 'payment_method',
#        'discount_applied', 'complaint_type', 'csat_score', 'escalations',
#        'email_open_rate', 'marketing_click_rate', 'nps_score',
#        'survey_response', 'referral_count', 'churn', 'tenure_group',
#        'is_zombie_user', 'usage_density', 'total_monthly_time', 'is_bouncer',
#        'session_strength_log', 'feature_intensity_log', 'is_slow_ghost',
#        'last_login_days_log', 'is_recency_danger', 'monthly_fee_log',
#        'value_score_log', 'payment_failures_clipped',
#        'is_high_friction_payment', 'payment_structural_risk',
#        'loyalty_shock_score', 'support_intensity_log',
#        'support_tickets_clipped'],
#       dtype='object')

# %%
num_features
# Out:
# ['monthly_logins',
#  'weekly_active_days',
#  'usage_density',
#  'total_monthly_time',
#  'session_strength_log',
#  'features_used',
#  'feature_intensity_log',
#  'usage_growth_rate',
#  'is_slow_ghost',
#  'last_login_days_log',
#  'is_recency_danger',
#  'monthly_fee_log',
#  'value_score_log',
#  'payment_failures_clipped',
#  'is_high_friction_payment',
#  'payment_structural_risk',
#  'loyalty_shock_score',
#  'support_intensity_log',
#  'discount_applied',
#  'is_zombie_user',
#  'is_bouncer',
#  'support_tickets_clipped']

# %%
sns.histplot(df_clean['loyalty_shock_score'],bins=5,kde=True,color='red')
# Out:
# <Axes: xlabel='loyalty_shock_score', ylabel='Count'>

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'features_used', 'usage_growth_rate', 'payment_method',
#        'discount_applied', 'complaint_type', 'csat_score', 'escalations',
#        'email_open_rate', 'marketing_click_rate', 'nps_score',
#        'survey_response', 'referral_count', 'churn', 'tenure_group',
#        'is_zombie_user', 'usage_density', 'total_monthly_time', 'is_bouncer',
#        'session_strength_log', 'feature_intensity_log', 'is_slow_ghost',
#        'last_login_days_log', 'is_recency_danger', 'monthly_fee_log',
#        'value_score_log', 'payment_failures_clipped',
#        'is_high_friction_payment', 'payment_structural_risk',
#        'loyalty_shock_score', 'support_intensity_log',
#        'support_tickets_clipped'],
#       dtype='object')

# %%
df_clean.complaint_type.describe()
# Out:
# count         10000
# unique            4
# top       Technical
# freq           3498
# Name: complaint_type, dtype: object

# %%
df_clean.complaint_type.value_counts()
# Out:
# complaint_type
# Technical       3498
# Billing         2427
# No complaint    2045
# Service         2030
# Name: count, dtype: int64

# %%
sns.histplot(df_clean.complaint_type,bins=10,kde=True,color='red')
# Out:
# <Axes: xlabel='complaint_type', ylabel='Count'>

# %%
df_clean.loc[df_clean['support_tickets_clipped'] == 0, 'complaint_type'] = 'No complaint'

# %%
print(df_clean['complaint_type'].value_counts())
# Out:
# complaint_type
# No complaint    4414
# Technical       2470
# Billing         1672
# Service         1444
# Name: count, dtype: int64

# %%
df_clean.csat_score.value_counts()
# Out:
# csat_score
# 4.0    3523
# 3.0    3380
# 5.0    1554
# 2.0    1322
# 1.0     221
# Name: count, dtype: int64

# %%
unhappy_silent = df_clean[(df_clean['complaint_type'] == 'No complaint') & (df_clean['csat_score'] <= 2)]
print(f"Number of 'No complaint' users who are actually unhappy: {len(unhappy_silent)}")
# Out:
# Number of 'No complaint' users who are actually unhappy: 682

# %%
df_clean['is_hidden_dissatisfaction'] = (
    (df_clean['complaint_type'] == 'No complaint') & 
    (df_clean['csat_score'] <= 2)
).astype(int)

# %%
if 'is_hidden_dissatisfaction' not in num_features:
    num_features.append('is_hidden_dissatisfaction')

# %%
cat_features.append('complaint_type')

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'features_used', 'usage_growth_rate', 'payment_method',
#        'discount_applied', 'complaint_type', 'csat_score', 'escalations',
#        'email_open_rate', 'marketing_click_rate', 'nps_score',
#        'survey_response', 'referral_count', 'churn', 'tenure_group',
#        'is_zombie_user', 'usage_density', 'total_monthly_time', 'is_bouncer',
#        'session_strength_log', 'feature_intensity_log', 'is_slow_ghost',
#        'last_login_days_log', 'is_recency_danger', 'monthly_fee_log',
#        'value_score_log', 'payment_failures_clipped',
#        'is_high_friction_payment', 'payment_structural_risk',
#        'loyalty_shock_score', 'support_intensity_log',
#        'support_tickets_clipped', 'is_hidden_dissatisfaction'],
#       dtype='object')

# %%
df_clean.escalations.value_counts()
# Out:
# escalations
# 0    7445
# 1    2216
# 2     296
# 3      39
# 4       4
# Name: count, dtype: int64

# %%
df_clean['escalations_clipped'] = df_clean['escalations'].clip(upper=2)

# %%
num_features.append('escalations_clipped')

# %%
sns.histplot(df_clean['escalations_clipped'],kde=True,bins=3,color='red')
# Out:
# <Axes: xlabel='escalations_clipped', ylabel='Count'>

# %%
df_clean = df_clean.drop(columns=['escalations'])

# %%
num_features
# Out:
# ['monthly_logins',
#  'weekly_active_days',
#  'usage_density',
#  'total_monthly_time',
#  'session_strength_log',
#  'features_used',
#  'feature_intensity_log',
#  'usage_growth_rate',
#  'is_slow_ghost',
#  'last_login_days_log',
#  'is_recency_danger',
#  'monthly_fee_log',
#  'value_score_log',
#  'payment_failures_clipped',
#  'is_high_friction_payment',
#  'payment_structural_risk',
#  'loyalty_shock_score',
#  'support_intensity_log',
#  'discount_applied',
#  'is_zombie_user',
#  'is_bouncer',
#  'support_tickets_clipped',
#  'is_hidden_dissatisfaction',
#  'escalations_clipped']

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'features_used', 'usage_growth_rate', 'payment_method',
#        'discount_applied', 'complaint_type', 'csat_score', 'email_open_rate',
#        'marketing_click_rate', 'nps_score', 'survey_response',
#        'referral_count', 'churn', 'tenure_group', 'is_zombie_user',
#        'usage_density', 'total_monthly_time', 'is_bouncer',
#        'session_strength_log', 'feature_intensity_log', 'is_slow_ghost',
#        'last_login_days_log', 'is_recency_danger', 'monthly_fee_log',
#        'value_score_log', 'payment_failures_clipped',
#        'is_high_friction_payment', 'payment_structural_risk',
#        'loyalty_shock_score', 'support_intensity_log',
#        'support_tickets_clipped', 'is_hidden_dissatisfaction',
#        'escalations_clipped'],
#       dtype='object')

# %%
df_clean.email_open_rate.value_counts()
# Out:
# email_open_rate
# 0.34    153
# 0.68    148
# 0.48    147
# 0.45    146
# 0.61    146
#        ...
# 0.43    102
# 0.51     95
# 0.38     88
# 0.10     71
# 0.90     66
# Name: count, Length: 81, dtype: int64

# %%
df_clean.email_open_rate.describe()
# Out:
# count    10000.000000
# mean         0.499610
# std          0.231601
# min          0.100000
# 25%          0.300000
# 50%          0.500000
# 75%          0.700000
# max          0.900000
# Name: email_open_rate, dtype: float64

# %%
min_val, max_val = 0.1, 0.9
df_clean['email_open_rate_fixed'] = (df_clean['email_open_rate'] - min_val) / (max_val - min_val)

# %%
df_clean['email_open_rate_fixed'] = df_clean['email_open_rate_fixed']**2

# %%
threshold = df_clean['email_open_rate_fixed'].quantile(0.10)
df_clean.loc[df_clean['email_open_rate_fixed'] <= threshold, 'email_open_rate_fixed'] = 0

# %%
num_features.append('email_open_rate_fixed')

# %%
df_clean = df_clean.drop(columns=['email_open_rate'])

# %%
sns.histplot(df_clean['email_open_rate_fixed'],kde=True,bins=5,color='red')
# Out:
# <Axes: xlabel='email_open_rate_fixed', ylabel='Count'>

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'features_used', 'usage_growth_rate', 'payment_method',
#        'discount_applied', 'complaint_type', 'csat_score',
#        'marketing_click_rate', 'nps_score', 'survey_response',
#        'referral_count', 'churn', 'tenure_group', 'is_zombie_user',
#        'usage_density', 'total_monthly_time', 'is_bouncer',
#        'session_strength_log', 'feature_intensity_log', 'is_slow_ghost',
#        'last_login_days_log', 'is_recency_danger', 'monthly_fee_log',
#        'value_score_log', 'payment_failures_clipped',
#        'is_high_friction_payment', 'payment_structural_risk',
#        'loyalty_shock_score', 'support_intensity_log',
#        'support_tickets_clipped', 'is_hidden_dissatisfaction',
#        'escalations_clipped', 'email_open_rate_fixed'],
#       dtype='object')

# %%
df_clean.marketing_click_rate.value_counts()
# Out:
# marketing_click_rate
# 0.16    234
# 0.11    228
# 0.40    226
# 0.19    225
# 0.21    223
# 0.38    222
# 0.07    220
# 0.27    219
# 0.23    219
# 0.24    219
# 0.13    212
# 0.15    212
# 0.12    212
# 0.41    211
# 0.30    211
# 0.02    210
# 0.36    210
# 0.17    209
# 0.20    209
# 0.10    209
# 0.43    209
# 0.03    208
# 0.39    207
# 0.48    206
# 0.46    206
# 0.09    203
# 0.32    203
# 0.31    203
# 0.28    201
# 0.49    201
# 0.44    200
# 0.22    199
# 0.34    197
# 0.29    197
# 0.06    196
# 0.26    196
# 0.04    195
# 0.08    194
# 0.42    194
# 0.37    193
# 0.18    193
# 0.14    192
# 0.35    190
# 0.45    183
# 0.25    182
# 0.05    179
# 0.47    179
# 0.33    170
# 0.50     93
# 0.01     91
# Name: count, dtype: int64

# %%
df_clean.marketing_click_rate.describe()
# Out:
# count    10000.000000
# mean         0.253575
# std          0.140532
# min          0.010000
# 25%          0.130000
# 50%          0.250000
# 75%          0.380000
# max          0.500000
# Name: marketing_click_rate, dtype: float64

# %%
sns.histplot(df_clean['marketing_click_rate'],kde=True,bins=5,color='red')
# Out:
# <Axes: xlabel='marketing_click_rate', ylabel='Count'>

# %%
df_clean['email_open_rate'] = df_raw['email_open_rate']

# %%
df_clean['marketing_click_rate_fixed'] = np.minimum(df_clean['marketing_click_rate'], df_clean['email_open_rate'])

# %%
df_clean['engagement_efficiency'] = df_clean['marketing_click_rate_fixed'] / (df_clean['email_open_rate'] + 0.01)

# %%
num_features.append('engagement_efficiency')
df_clean = df_clean.drop(columns=['marketing_click_rate'])

# %%
df_clean = df_clean.drop(columns=['email_open_rate'])

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'features_used', 'usage_growth_rate', 'payment_method',
#        'discount_applied', 'complaint_type', 'csat_score', 'nps_score',
#        'survey_response', 'referral_count', 'churn', 'tenure_group',
#        'is_zombie_user', 'usage_density', 'total_monthly_time', 'is_bouncer',
#        'session_strength_log', 'feature_intensity_log', 'is_slow_ghost',
#        'last_login_days_log', 'is_recency_danger', 'monthly_fee_log',
#        'value_score_log', 'payment_failures_clipped',
#        'is_high_friction_payment', 'payment_structural_risk',
#        'loyalty_shock_score', 'support_intensity_log',
#        'support_tickets_clipped', 'is_hidden_dissatisfaction',
#        'escalations_clipped', 'email_open_rate_fixed',
#        'marketing_click_rate_fixed', 'engagement_efficiency'],
#       dtype='object')

# %%
df_clean.nps_score.describe()
# Out:
# count    10000.000000
# mean        19.110500
# std         38.936619
# min       -100.000000
# 25%         -7.000000
# 50%         19.000000
# 75%         46.000000
# max        100.000000
# Name: nps_score, dtype: float64

# %%
df_clean['nps_normalized'] = (df_clean['nps_score'] + 100) / 200

# %%
df_clean['loyalty_resilience'] = df_clean['nps_normalized'] * (1 / (df_clean['support_intensity_log'] + 1))

# %%
df_clean['is_passive_promoter'] = ((df_clean['nps_score'] >= 70) & (df_clean['referral_count'] == 0)).astype(int)

# %%
for f in ['nps_normalized', 'loyalty_resilience', 'is_passive_promoter']:
    if f not in num_features:
        num_features.append(f)

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'features_used', 'usage_growth_rate', 'payment_method',
#        'discount_applied', 'complaint_type', 'csat_score', 'nps_score',
#        'survey_response', 'referral_count', 'churn', 'tenure_group',
#        'is_zombie_user', 'usage_density', 'total_monthly_time', 'is_bouncer',
#        'session_strength_log', 'feature_intensity_log', 'is_slow_ghost',
#        'last_login_days_log', 'is_recency_danger', 'monthly_fee_log',
#        'value_score_log', 'payment_failures_clipped',
#        'is_high_friction_payment', 'payment_structural_risk',
#        'loyalty_shock_score', 'support_intensity_log',
#        'support_tickets_clipped', 'is_hidden_dissatisfaction',
#        'escalations_clipped', 'email_open_rate_fixed',
#        'marketing_click_rate_fixed', 'engagement_efficiency', 'nps_normalized',
# ...

# %%
if 'nps_score' in num_features:
    num_features.remove('nps_score')

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'features_used', 'usage_growth_rate', 'payment_method',
#        'discount_applied', 'complaint_type', 'csat_score', 'nps_score',
#        'survey_response', 'referral_count', 'churn', 'tenure_group',
#        'is_zombie_user', 'usage_density', 'total_monthly_time', 'is_bouncer',
#        'session_strength_log', 'feature_intensity_log', 'is_slow_ghost',
#        'last_login_days_log', 'is_recency_danger', 'monthly_fee_log',
#        'value_score_log', 'payment_failures_clipped',
#        'is_high_friction_payment', 'payment_structural_risk',
#        'loyalty_shock_score', 'support_intensity_log',
#        'support_tickets_clipped', 'is_hidden_dissatisfaction',
#        'escalations_clipped', 'email_open_rate_fixed',
#        'marketing_click_rate_fixed', 'engagement_efficiency', 'nps_normalized',
# ...

# %%
if 'nps_score' in df_clean.columns:
    df_clean = df_clean.drop(columns=['nps_score'])

# %%
df_clean.survey_response.describe()
# Out:
# count         10000
# unique            3
# top       Satisfied
# freq           4975
# Name: survey_response, dtype: object

# %%
sns.histplot(df_clean['survey_response'],bins=10,kde=True,color='teal')
# Out:
# <Axes: xlabel='survey_response', ylabel='Count'>

# %%
df_clean.survey_response.value_counts()
# Out:
# survey_response
# Satisfied      4975
# Neutral        2978
# Unsatisfied    2047
# Name: count, dtype: int64

# %%
df_clean = df_clean.drop(columns=['survey_response'])

# %%
if 'survey_response' in cat_features:
    cat_features.remove('survey_response')

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'features_used', 'usage_growth_rate', 'payment_method',
#        'discount_applied', 'complaint_type', 'csat_score', 'referral_count',
#        'churn', 'tenure_group', 'is_zombie_user', 'usage_density',
#        'total_monthly_time', 'is_bouncer', 'session_strength_log',
#        'feature_intensity_log', 'is_slow_ghost', 'last_login_days_log',
#        'is_recency_danger', 'monthly_fee_log', 'value_score_log',
#        'payment_failures_clipped', 'is_high_friction_payment',
#        'payment_structural_risk', 'loyalty_shock_score',
#        'support_intensity_log', 'support_tickets_clipped',
#        'is_hidden_dissatisfaction', 'escalations_clipped',
#        'email_open_rate_fixed', 'marketing_click_rate_fixed',
#        'engagement_efficiency', 'nps_normalized', 'loyalty_resilience',
#        'is_passive_promoter'],
# ...

# %%
df_clean.referral_count.describe()
# Out:
# count    10000.0000
# mean         0.9922
# std          0.9939
# min          0.0000
# 25%          0.0000
# 50%          1.0000
# 75%          2.0000
# max          7.0000
# Name: referral_count, dtype: float64

# %%
df_clean.referral_count.value_counts()
# Out:
# referral_count
# 0    3704
# 1    3671
# 2    1841
# 3     613
# 4     134
# 5      29
# 6       7
# 7       1
# Name: count, dtype: int64

# %%
df_clean['referral_count_clipped'] = df_clean['referral_count'].clip(upper=3)

# %%
df_clean['is_advocate'] = (df_clean['referral_count'] > 0).astype(int)

# %%
for f in ['referral_count_clipped', 'is_advocate']:
    if f not in num_features:
        num_features.append(f)

# %%
df_clean.drop(columns=['referral_count'],inplace=True)

# %%
df_clean.columns
# Out:
# Index(['gender', 'age', 'city', 'customer_segment', 'signup_channel',
#        'contract_type', 'monthly_logins', 'weekly_active_days',
#        'features_used', 'usage_growth_rate', 'payment_method',
#        'discount_applied', 'complaint_type', 'csat_score', 'churn',
#        'tenure_group', 'is_zombie_user', 'usage_density', 'total_monthly_time',
#        'is_bouncer', 'session_strength_log', 'feature_intensity_log',
#        'is_slow_ghost', 'last_login_days_log', 'is_recency_danger',
#        'monthly_fee_log', 'value_score_log', 'payment_failures_clipped',
#        'is_high_friction_payment', 'payment_structural_risk',
#        'loyalty_shock_score', 'support_intensity_log',
#        'support_tickets_clipped', 'is_hidden_dissatisfaction',
#        'escalations_clipped', 'email_open_rate_fixed',
#        'marketing_click_rate_fixed', 'engagement_efficiency', 'nps_normalized',
#        'loyalty_resilience', 'is_passive_promoter', 'referral_count_clipped',
# ...

# %%
df_clean.churn.describe()
# Out:
# count    10000.000000
# mean         0.102100
# std          0.302795
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: churn, dtype: float64

# %%
df_clean.churn.value_counts()
# Out:
# churn
# 0    8979
# 1    1021
# Name: count, dtype: int64

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 43 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   gender                      10000 non-null  object
#  1   age                         10000 non-null  int64
#  2   city                        10000 non-null  object
#  3   customer_segment            10000 non-null  object
#  4   signup_channel              10000 non-null  object
#  5   contract_type               10000 non-null  int64
#  6   monthly_logins              10000 non-null  int64
#  7   weekly_active_days          10000 non-null  int64
#  8   features_used               10000 non-null  int64
#  9   usage_growth_rate           10000 non-null  float64
#  10  payment_method              10000 non-null  object
#  11  discount_applied            10000 non-null  int64
#  12  complaint_type              10000 non-null  object
# ...

# %%
print(df_clean.groupby('gender')['churn'].mean())
# Out:
# gender
# Female    0.101063
# Male      0.103132
# Name: churn, dtype: float64

# %%
print(df_clean[['age', 'churn']].corr())
# Out:
#             age     churn
# age    1.000000  0.010155
# churn  0.010155  1.000000

# %%
df_clean.drop(columns=['gender'],inplace=True)

# %%
bins = [0, 30, 55, 100]
labels = ['Young_Adult', 'Mid_Life', 'Senior']

# %%
df_clean['age_group'] = pd.cut(df_clean['age'], bins=bins, labels=labels)

# %%
age_signal = df_clean.groupby('age_group')['churn'].mean()
print("Churn Rate by Age Group:")
print(age_signal)
# Out:
# Churn Rate by Age Group:
# age_group
# Young_Adult    0.097454
# Mid_Life       0.100589
# Senior         0.107316
# Name: churn, dtype: float64
# C:\Users\jaisw\AppData\Local\Temp\ipykernel_21160\1192668933.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_signal = df_clean.groupby('age_group')['churn'].mean()

# %%
age_signal = df_clean.groupby('age_group', observed=False)['churn'].mean()

# %%
df_clean.drop(columns=['age'],inplace=True)

# %%
df_clean.columns
# Out:
# Index(['city', 'customer_segment', 'signup_channel', 'contract_type',
#        'monthly_logins', 'weekly_active_days', 'features_used',
#        'usage_growth_rate', 'payment_method', 'discount_applied',
#        'complaint_type', 'csat_score', 'churn', 'tenure_group',
#        'is_zombie_user', 'usage_density', 'total_monthly_time', 'is_bouncer',
#        'session_strength_log', 'feature_intensity_log', 'is_slow_ghost',
#        'last_login_days_log', 'is_recency_danger', 'monthly_fee_log',
#        'value_score_log', 'payment_failures_clipped',
#        'is_high_friction_payment', 'payment_structural_risk',
#        'loyalty_shock_score', 'support_intensity_log',
#        'support_tickets_clipped', 'is_hidden_dissatisfaction',
#        'escalations_clipped', 'email_open_rate_fixed',
#        'marketing_click_rate_fixed', 'engagement_efficiency', 'nps_normalized',
#        'loyalty_resilience', 'is_passive_promoter', 'referral_count_clipped',
#        'is_advocate', 'age_group'],
# ...

# %%
num_features
# Out:
# ['monthly_logins',
#  'weekly_active_days',
#  'usage_density',
#  'total_monthly_time',
#  'session_strength_log',
#  'features_used',
#  'feature_intensity_log',
#  'usage_growth_rate',
#  'is_slow_ghost',
#  'last_login_days_log',
#  'is_recency_danger',
#  'monthly_fee_log',
#  'value_score_log',
#  'payment_failures_clipped',
#  'is_high_friction_payment',
#  'payment_structural_risk',
#  'loyalty_shock_score',
#  'support_intensity_log',
#  'discount_applied',
#  'is_zombie_user',
#  'is_bouncer',
#  'support_tickets_clipped',
#  'is_hidden_dissatisfaction',
#  'escalations_clipped',
#  'email_open_rate_fixed',
#  'engagement_efficiency',
#  'nps_normalized',
#  'loyalty_resilience',
#  'is_passive_promoter',
#  'referral_count_clipped',
#  'is_advocate']

# %%
cat_features.remove('complaint_type')

# %%
cat_features
# Out:
# ['city', 'signup_channel', 'payment_method', 'tenure_group', 'complaint_type']

# %%
df_clean.contract_type.value_counts()
# Out:
# contract_type
# 1    4967
# 2    3050
# 3    1983
# Name: count, dtype: int64

# %%
cat_features.extend(['customer_segment','contract_type'])

# %%
num_features.append('csat_score')

# %%
cat_features
# Out:
# ['city',
#  'signup_channel',
#  'payment_method',
#  'tenure_group',
#  'complaint_type',
#  'customer_segment',
#  'contract_type']

# %%
num_features
# Out:
# ['monthly_logins',
#  'weekly_active_days',
#  'usage_density',
#  'total_monthly_time',
#  'session_strength_log',
#  'features_used',
#  'feature_intensity_log',
#  'usage_growth_rate',
#  'is_slow_ghost',
#  'last_login_days_log',
#  'is_recency_danger',
#  'monthly_fee_log',
#  'value_score_log',
#  'payment_failures_clipped',
#  'is_high_friction_payment',
#  'payment_structural_risk',
#  'loyalty_shock_score',
#  'support_intensity_log',
#  'discount_applied',
#  'is_zombie_user',
#  'is_bouncer',
#  'support_tickets_clipped',
#  'is_hidden_dissatisfaction',
#  'escalations_clipped',
#  'email_open_rate_fixed',
#  'engagement_efficiency',
#  'nps_normalized',
#  'loyalty_resilience',
#  'is_passive_promoter',
#  'referral_count_clipped',
#  'is_advocate',
#  'csat_score']

# %%
print(f"Final Count: {len(num_features)} Numerical, {len(cat_features)} Categorical")
# Out:
# Final Count: 32 Numerical, 7 Categorical

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 42 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   city                        10000 non-null  object
#  1   customer_segment            10000 non-null  object
#  2   signup_channel              10000 non-null  object
#  3   contract_type               10000 non-null  int64
#  4   monthly_logins              10000 non-null  int64
#  5   weekly_active_days          10000 non-null  int64
#  6   features_used               10000 non-null  int64
#  7   usage_growth_rate           10000 non-null  float64
#  8   payment_method              10000 non-null  object
#  9   discount_applied            10000 non-null  int64
#  10  complaint_type              10000 non-null  object
#  11  csat_score                  10000 non-null  float64
#  12  churn                       10000 non-null  int64
# ...

# %%
df_clean.drop(columns=['marketing_click_rate_fixed', 'age_group'],inplace=True)

# %%
for col in cat_features:
    if col in df_clean.columns:
        df_clean[col] = df_clean[col].astype('object')

# %%
for col in num_features:
    if col in df_clean.columns:
        df_clean[col] = df_clean[col].astype('float64')

# %%
print(df_clean[cat_features].dtypes)
# Out:
# city                object
# signup_channel      object
# payment_method      object
# tenure_group        object
# complaint_type      object
# customer_segment    object
# contract_type       object
# dtype: object

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 40 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   city                       10000 non-null  object
#  1   customer_segment           10000 non-null  object
#  2   signup_channel             10000 non-null  object
#  3   contract_type              10000 non-null  object
#  4   monthly_logins             10000 non-null  float64
#  5   weekly_active_days         10000 non-null  float64
#  6   features_used              10000 non-null  float64
#  7   usage_growth_rate          10000 non-null  float64
#  8   payment_method             10000 non-null  object
#  9   discount_applied           10000 non-null  float64
#  10  complaint_type             10000 non-null  object
#  11  csat_score                 10000 non-null  float64
#  12  churn                      10000 non-null  int64
# ...
